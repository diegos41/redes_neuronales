# %% [markdown]
# # Librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
import random

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# # Datos

# %% [markdown]
# ## Datasets

# %%
class CustomDataset(Dataset):
    def __init__(self,dataset):
        self.dataset=dataset
    # Redefinimos el método .__len__()
    def __len__(self):
        return len(self.dataset)
    # Redefinimos el método .__getitem__()
    def __getitem__(self,i):
        image,label=self.dataset[i]
        input  = image
        output = image # Retornamos la imagen como salida
        return input, output

# %%
transform = transforms.ToTensor() # Para pasar de imágene PIL a tensores
train_set_orig = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set_orig = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)
train_set = CustomDataset(train_set_orig)
valid_set = CustomDataset(valid_set_orig)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 11.1MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 165kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.73MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 22.6MB/s]

# %% [markdown]
# ## Diccionario de Clases

# %%
class_names = {
    0: "T-shirt/top", # Remera manga corta o top
    1: "Trouser",     # Pantalón
    2: "Pullover",    # Buzo
    3: "Dress",       # Vestido
    4: "Coat",        # Abrigo
    5: "Sandal",      # Sandalia
    6: "Shirt",       # Camisa
    7: "Sneaker",     # Zapatilla
    8: "Bag",         # Bolso
    9: "Ankle boot"   # Bota
}

# %% [markdown]
# ## Visualización de los Datos

# %%
fig, axes = plt.subplots(3, 3, figsize=(8, 8))
for i in range(3):
  for j in range(3) :
    index = i * 3 + j
    image, label = train_set_orig[index]
    axes[i, j].imshow(image.squeeze(), cmap='gray')
    axes[i, j].set_title(class_names[label], fontsize=10)
    axes[i, j].axis('off')

plt.suptitle("Mosaico de Imágenes Fashion-MNIST", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Autoencoder

# %%
# 4.1)
class AutoencoderConvolutional(nn.Module):
    """
    Autoencoder convolucional profundo para imágenes Fashion-MNIST (1x28x28),
    compuesto por un módulo codificador convolucional, un cuello de botella
    opcional completamente conectado y un decodificador convolucional transpuesto.

    Parameters
    ----------
    p1 : float, optional
        Probabilidad de dropout aplicada al final del codificador convolucional.
        Controla el nivel de regularización (default = 0.2).

    p2 : float, optional
        Probabilidad de dropout aplicada en el cuello de botella completamente conectado.
        Permite regularizar el espacio latente. Por defecto no se aplica dropout (default = 0.0).

    n : int, optional
        Dimensión del espacio latente en el cuello de botella fully-connected.
        Determina el grado de compresión de la representación (default = 128).

    filter_num1 : int, optional
        Número de filtros de la primera convolución del encoder.
        Define la profundidad inicial del mapa de características
        (default = 8).

    filter_num2 : int, optional
        Número de filtros de la segunda convolución del encoder.
        Aumenta la capacidad representacional del modelo antes del pooling
        (default = 16).

    ks1 : int, optional
        Tamaño del kernel de la primera convolución del encoder (default = 3).

    ks2 : int, optional
        Tamaño del kernel de la segunda convolución del encoder (default = 3).

    ks3 : int, optional
        Tamaño del kernel de la primera convolución transpuesta del decoder (default = 2).

    ks4 : int, optional
        Tamaño del kernel de la segunda convolución transpuesta del decoder (default = 5).

    str1 : int, optional
        Stride de la primera convolución del encoder (default = 1).

    str2 : int, optional
        Stride de la segunda convolución del encoder (default = 1).

    str3 : int, optional
        Stride de la primera convolución transpuesta del decoder (default = 2).

    str4 : int, optional
        Stride de la segunda convolución transpuesta del decoder (default = 1).

    pad1 : int, optional
        Padding de la primera convolución del encoder (default = 0).

    pad2 : int, optional
        Padding de la segunda convolución del encoder (default = 0).

    pad3 : int, optional
        Padding de la primera convolución transpuesta del decoder (default = 0).

    pad4 : int, optional
        Padding de la segunda convolución transpuesta del decoder (default = 0).

    dil1 : int, optional
        Dilatación de la primera convolución del encoder (default = 1).

    dil2 : int, optional
        Dilatación de la segunda convolución del encoder (default = 1).

    dil3 : int, optional
        Dilatación de la primera convolución transpuesta del decoder (default = 1).

    dil4 : int, optional
        Dilatación de la segunda convolución transpuesta del decoder (default = 1).

    pool_size : tuple of int, optional
        Tamaño del max-pooling aplicado luego de la convolución del encoder.
        Reduce la resolución espacial de los mapas de características
        (default = (2, 2)).

    use_bn : bool, optional
        Indica si se utiliza un cuello de botella lineal completamente conectado.
        Si True, se incluye una capa fully-connected que comprime la representación
        a dimensión n. Si False, se omite el cuello de botella y se mantiene la
        representación convolucional plana (default = True).
    """
    def __init__(self, p1=0.2, p2=0.0, n=128,
                filter_num1=8, filter_num2=16,
                ks1=3, ks2=3, ks3=2, ks4=5,
                str1=1, str2=1, str3=2, str4=1,
                pad1=0, pad2=0, pad3=0, pad4=0,
                dil1=1, dil2=1, dil3=1, dil4=1,
                pool_size=(2,2), use_bn = True):
        super().__init__()

        conv1_out = ((28 + 2*pad1 - dil1*(ks1 - 1) - 1) // str1) + 1
        conv2_out = ((conv1_out + 2*pad2 - dil2*(ks2 - 1) - 1) // str2) + 1

        h_after_pool = conv2_out // pool_size[0]
        w_after_pool = conv2_out // pool_size[1]

        # conv_trans1_out = ((h_after_pool - 1)*str3 - 2*pad3 + dil3*(ks3 - 1) + 1)
        # conv_trans2_out = ((conv_trans1_out - 1)*str4 - 2*pad4 + dil4*(ks4 - 1) + 1)


        self.flat_size = filter_num2 * h_after_pool * w_after_pool

        # -------- Encoder --------
        self.encoder = nn.Sequential(
            nn.Conv2d(1, filter_num1, kernel_size=ks1, stride=str1, padding=pad1, dilation=dil1),  # (1,28,28) -> (filter_num1,conv1_out,conv1_out)
            nn.ReLU(),
            nn.Conv2d(filter_num1, filter_num2, kernel_size=ks2, stride=str2, padding=pad2, dilation=dil2), # (filter_num1,conv1_out,conv1_out) -> (filter_num2,conv2_out,conv2_out)
            nn.ReLU(),
            nn.MaxPool2d(pool_size),             # (filter_num2,h_after_pool,w_after_pool)
            nn.Dropout(p1)
        )

        # -------- Bottleneck --------
        if (use_bn):
            self.bottleneck = nn.Sequential(
                nn.Flatten(),                   # (filter_num2,h_after_pool,w_after_pool) -> (flat_size)
                nn.Linear(self.flat_size, n),   # (flat_size -> n)
                nn.ReLU(),
                nn.Dropout(p2),
                nn.Linear(n, self.flat_size),   # (n -> flat_size)
                nn.ReLU()
            )
        else:
            self.bottleneck = nn.Sequential(
                nn.Flatten(),
                nn.Identity()
            )

        # -------- Decoder --------
        self.decoder = nn.Sequential(
            nn.Unflatten(1, (filter_num2, h_after_pool, w_after_pool)),  # (flat_size) -> (filter_num2,h_after_pool,w_after_pool)
            nn.ConvTranspose2d(filter_num2, filter_num1, kernel_size=ks3, stride=str3, padding=pad3, dilation=dil3), # (filter_num2,h_after_pool,w_after_pool) -> (filter_num1,conv_trans1_out,conv_trans1_out)
            nn.ReLU(),
            nn.ConvTranspose2d(filter_num1, 1, kernel_size=ks4, stride=str4, padding=pad4, dilation=dil4), # (filter_num1,conv_trans2_out,conv_trans2_out) -> (1,28,28)
            nn.Sigmoid()                       # salida en [0,1]
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottleneck(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# # Clasificador

# %%
class Classifier(nn.Module):
    """
    Red neuronal clasificadora que reutiliza el codificador de un autoencoder
    convolucional. Opcionalmente incorpora el cuello
    de botella fully-connected del autoencoder como parte del pipeline de
    extracción de características.

    La arquitectura consta de tres etapas:
    (i) un encoder convolucional (proveniente del autoencoder),
    (ii) un cuello de botella opcional o aplanado directo de las características,
    y (iii) un clasificador completamente conectado que produce las predicciones
    sobre las 10 clases de Fashion-MNIST.

    Parameters
    ----------
    autoencoder : AutoencoderConvolutional
        Instancia del autoencoder desde el cual se
        reutiliza el encoder (y opcionalmente el bottleneck).

    use_bn : bool, optional
        Indica si se utiliza el cuello de botella fully-connected del autoencoder.
        Si True, se emplea la representación latente aprendida por el autoencoder.
        Si False, se omite el bottleneck y se utiliza directamente la salida
        convolucional del encoder aplanada (default = False).

    n1 : int, optional
        Número de neuronas de la primera capa fully-connected del clasificador
        (default = 128).

    n2 : int, optional
        Número de neuronas de la segunda capa fully-connected del clasificador
        (default = 64).

    p : float, optional
        Probabilidad de dropout aplicada en las capas del clasificador para
        regularización (default = 0.2).
    """
    def __init__(self, autoencoder, use_bn=False,
                 n1=128, n2=64, p=0.2):
        super().__init__()

        self.encoder = autoencoder.encoder

        if use_bn:
          self.bottleneck = nn.Sequential(
              autoencoder.bottleneck[0],  # Flatten
              autoencoder.bottleneck[1],  # Linear(flat → n)
              autoencoder.bottleneck[2],  # ReLU
          )
          latent_dim = autoencoder.bottleneck[1].out_features
        else:
          self.bottleneck = nn.Flatten()
          latent_dim = autoencoder.flat_size

        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, n1),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n1, n2),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n2, 10),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottleneck(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# # Pre-entrenamiento

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_inc_loss = 0

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Statistics
        train_inc_loss += loss.item()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * dataloader.batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    avg_train_inc_loss = train_inc_loss / num_batches

    return avg_train_inc_loss

# %%
def valid_loop_autoencoder(dataloader, model, loss_fn):
    model.eval()
    num_batches = len(dataloader)
    valid_loss = 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)

            # Statistics
            valid_loss += loss_fn(pred, y).item()

    avg_valid_loss = valid_loss / num_batches
    print(f"Test Error: Avg loss: {avg_valid_loss:>8f} \n")

    return avg_valid_loss

# %% [markdown]
# ## Configuraciones (baseline)

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128 # Misma cantidad de neuronas que de pixeles por imagen
pre_trained_autoencoder = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=16, filter_num2=32).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %% [markdown]
# ## Resultados

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 40
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.163348  [  100/60000]
# loss: 0.023976  [10100/60000]
# loss: 0.018184  [20100/60000]
# loss: 0.016813  [30100/60000]
# loss: 0.015417  [40100/60000]
# loss: 0.014182  [50100/60000]
# Test Error: Avg loss: 0.012646
#
# Test Error: Avg loss: 0.012744
#
# Epoch 2
# -------------------------------
# loss: 0.013013  [  100/60000]
# loss: 0.012699  [10100/60000]
# loss: 0.011576  [20100/60000]
# loss: 0.012524  [30100/60000]
# loss: 0.011950  [40100/60000]
# loss: 0.010986  [50100/60000]
# Test Error: Avg loss: 0.010033
#
# Test Error: Avg loss: 0.010149
#
# Epoch 3
# -------------------------------
# loss: 0.011297  [  100/60000]
# loss: 0.009953  [10100/60000]
# loss: 0.011231  [20100/60000]
# loss: 0.010132  [30100/60000]
# loss: 0.009921  [40100/60000]
# loss: 0.009413  [50100/60000]
# Test Error: Avg loss: 0.008640
#
# Test Error: Avg loss: 0.008768
#
# Epoch 4
# -------------------------------
# loss: 0.008350  [  100/60000]
# loss: 0.008436  [10100/60000]
# loss: 0.008672  [20100/60000]
# loss: 0.008396  [30100/60000]
# loss: 0.008858  [40100/60000]
# loss: 0.009496  [50100/60000]
# Test Error: Avg loss: 0.007912
#
# Test Error: Avg loss: 0.008049
#
# Epoch 5
# -------------------------------
# loss: 0.008213  [  100/60000]
# loss: 0.008445  [10100/60000]
# loss: 0.007949  [20100/60000]
# loss: 0.007865  [30100/60000]
# loss: 0.008251  [40100/60000]
# loss: 0.008239  [50100/60000]
# Test Error: Avg loss: 0.007409
#
# Test Error: Avg loss: 0.007558
#
# Epoch 6
# -------------------------------
# loss: 0.007825  [  100/60000]
# loss: 0.008053  [10100/60000]
# loss: 0.007525  [20100/60000]
# loss: 0.007267  [30100/60000]
# loss: 0.007167  [40100/60000]
# loss: 0.007980  [50100/60000]
# Test Error: Avg loss: 0.007086
#
# Test Error: Avg loss: 0.007238
#
# Epoch 7
# -------------------------------
# loss: 0.007614  [  100/60000]
# loss: 0.007268  [10100/60000]
# loss: 0.007933  [20100/60000]
# loss: 0.007094  [30100/60000]
# loss: 0.007278  [40100/60000]
# loss: 0.007205  [50100/60000]
# Test Error: Avg loss: 0.006853
#
# Test Error: Avg loss: 0.007018
#
# Epoch 8
# -------------------------------
# loss: 0.006986  [  100/60000]
# loss: 0.006630  [10100/60000]
# loss: 0.006692  [20100/60000]
# loss: 0.006386  [30100/60000]
# loss: 0.008098  [40100/60000]
# loss: 0.007601  [50100/60000]
# Test Error: Avg loss: 0.006624
#
# Test Error: Avg loss: 0.006797
#
# Epoch 9
# -------------------------------
# loss: 0.006893  [  100/60000]
# loss: 0.006847  [10100/60000]
# loss: 0.006815  [20100/60000]
# loss: 0.007145  [30100/60000]
# loss: 0.007229  [40100/60000]
# loss: 0.006256  [50100/60000]
# Test Error: Avg loss: 0.006496
#
# Test Error: Avg loss: 0.006681
#
# Epoch 10
# -------------------------------
# loss: 0.007794  [  100/60000]
# loss: 0.007433  [10100/60000]
# loss: 0.006814  [20100/60000]
# loss: 0.007370  [30100/60000]
# loss: 0.007785  [40100/60000]
# loss: 0.006792  [50100/60000]
# Test Error: Avg loss: 0.006363
#
# Test Error: Avg loss: 0.006551
#
# Epoch 11
# -------------------------------
# loss: 0.006506  [  100/60000]
# loss: 0.006681  [10100/60000]
# loss: 0.007153  [20100/60000]
# loss: 0.006812  [30100/60000]
# loss: 0.006730  [40100/60000]
# loss: 0.005905  [50100/60000]
# Test Error: Avg loss: 0.006237
#
# Test Error: Avg loss: 0.006429
#
# Epoch 12
# -------------------------------
# loss: 0.006817  [  100/60000]
# loss: 0.007435  [10100/60000]
# loss: 0.005586  [20100/60000]
# loss: 0.006973  [30100/60000]
# loss: 0.006915  [40100/60000]
# loss: 0.006572  [50100/60000]
# Test Error: Avg loss: 0.006155
#
# Test Error: Avg loss: 0.006354
#
# Epoch 13
# -------------------------------
# loss: 0.006686  [  100/60000]
# loss: 0.006434  [10100/60000]
# loss: 0.007294  [20100/60000]
# loss: 0.006459  [30100/60000]
# loss: 0.006251  [40100/60000]
# loss: 0.007028  [50100/60000]
# Test Error: Avg loss: 0.006115
#
# Test Error: Avg loss: 0.006322
#
# Epoch 14
# -------------------------------
# loss: 0.006844  [  100/60000]
# loss: 0.006807  [10100/60000]
# loss: 0.006170  [20100/60000]
# loss: 0.005562  [30100/60000]
# loss: 0.005891  [40100/60000]
# loss: 0.006706  [50100/60000]
# Test Error: Avg loss: 0.006147
#
# Test Error: Avg loss: 0.006364
#
# Epoch 15
# -------------------------------
# loss: 0.008192  [  100/60000]
# loss: 0.006919  [10100/60000]
# loss: 0.006838  [20100/60000]
# loss: 0.006836  [30100/60000]
# loss: 0.007125  [40100/60000]
# loss: 0.006059  [50100/60000]
# Test Error: Avg loss: 0.005951
#
# Test Error: Avg loss: 0.006169
#
# Epoch 16
# -------------------------------
# loss: 0.007284  [  100/60000]
# loss: 0.007167  [10100/60000]
# loss: 0.007535  [20100/60000]
# loss: 0.006316  [30100/60000]
# loss: 0.007233  [40100/60000]
# loss: 0.006092  [50100/60000]
# Test Error: Avg loss: 0.005896
#
# Test Error: Avg loss: 0.006121
#
# Epoch 17
# -------------------------------
# loss: 0.005444  [  100/60000]
# loss: 0.005992  [10100/60000]
# loss: 0.005786  [20100/60000]
# loss: 0.006446  [30100/60000]
# loss: 0.006346  [40100/60000]
# loss: 0.005617  [50100/60000]
# Test Error: Avg loss: 0.006007
#
# Test Error: Avg loss: 0.006231
#
# Epoch 18
# -------------------------------
# loss: 0.005993  [  100/60000]
# loss: 0.006889  [10100/60000]
# loss: 0.006756  [20100/60000]
# loss: 0.006013  [30100/60000]
# loss: 0.006799  [40100/60000]
# loss: 0.006871  [50100/60000]
# Test Error: Avg loss: 0.005809
#
# Test Error: Avg loss: 0.006045
#
# Epoch 19
# -------------------------------
# loss: 0.007366  [  100/60000]
# loss: 0.006138  [10100/60000]
# loss: 0.005525  [20100/60000]
# loss: 0.006830  [30100/60000]
# loss: 0.007701  [40100/60000]
# loss: 0.005735  [50100/60000]
# Test Error: Avg loss: 0.005715
#
# Test Error: Avg loss: 0.005947
#
# Epoch 20
# -------------------------------
# loss: 0.005941  [  100/60000]
# loss: 0.007286  [10100/60000]
# loss: 0.005795  [20100/60000]
# loss: 0.005847  [30100/60000]
# loss: 0.007294  [40100/60000]
# loss: 0.006417  [50100/60000]
# Test Error: Avg loss: 0.005733
#
# Test Error: Avg loss: 0.005974
#
# Epoch 21
# -------------------------------
# loss: 0.006004  [  100/60000]
# loss: 0.005507  [10100/60000]
# loss: 0.006893  [20100/60000]
# loss: 0.005374  [30100/60000]
# loss: 0.006843  [40100/60000]
# loss: 0.006637  [50100/60000]
# Test Error: Avg loss: 0.005667
#
# Test Error: Avg loss: 0.005912
#
# Epoch 22
# -------------------------------
# loss: 0.006233  [  100/60000]
# loss: 0.005899  [10100/60000]
# loss: 0.006127  [20100/60000]
# loss: 0.006594  [30100/60000]
# loss: 0.005948  [40100/60000]
# loss: 0.006058  [50100/60000]
# Test Error: Avg loss: 0.005691
#
# Test Error: Avg loss: 0.005942
#
# Epoch 23
# -------------------------------
# loss: 0.006365  [  100/60000]
# loss: 0.005865  [10100/60000]
# loss: 0.005328  [20100/60000]
# loss: 0.005850  [30100/60000]
# loss: 0.006629  [40100/60000]
# loss: 0.006648  [50100/60000]
# Test Error: Avg loss: 0.005594
#
# Test Error: Avg loss: 0.005845
#
# Epoch 24
# -------------------------------
# loss: 0.005465  [  100/60000]
# loss: 0.006496  [10100/60000]
# loss: 0.006931  [20100/60000]
# loss: 0.005483  [30100/60000]
# loss: 0.006953  [40100/60000]
# loss: 0.006728  [50100/60000]
# Test Error: Avg loss: 0.005550
#
# Test Error: Avg loss: 0.005804
#
# Epoch 25
# -------------------------------
# loss: 0.005627  [  100/60000]
# loss: 0.006508  [10100/60000]
# loss: 0.006199  [20100/60000]
# loss: 0.006115  [30100/60000]
# loss: 0.005842  [40100/60000]
# loss: 0.006346  [50100/60000]
# Test Error: Avg loss: 0.005549
#
# Test Error: Avg loss: 0.005808
#
# Epoch 26
# -------------------------------
# loss: 0.005780  [  100/60000]
# loss: 0.007381  [10100/60000]
# loss: 0.005520  [20100/60000]
# loss: 0.006173  [30100/60000]
# loss: 0.006716  [40100/60000]
# loss: 0.005540  [50100/60000]
# Test Error: Avg loss: 0.005574
#
# Test Error: Avg loss: 0.005840
#
# Epoch 27
# -------------------------------
# loss: 0.006828  [  100/60000]
# loss: 0.006059  [10100/60000]
# loss: 0.006142  [20100/60000]
# loss: 0.005360  [30100/60000]
# loss: 0.006332  [40100/60000]
# loss: 0.005757  [50100/60000]
# Test Error: Avg loss: 0.005458
#
# Test Error: Avg loss: 0.005723
#
# Epoch 28
# -------------------------------
# loss: 0.007068  [  100/60000]
# loss: 0.006022  [10100/60000]
# loss: 0.005463  [20100/60000]
# loss: 0.005937  [30100/60000]
# loss: 0.006984  [40100/60000]
# loss: 0.006701  [50100/60000]
# Test Error: Avg loss: 0.005472
#
# Test Error: Avg loss: 0.005740
#
# Epoch 29
# -------------------------------
# loss: 0.006435  [  100/60000]
# loss: 0.005756  [10100/60000]
# loss: 0.006310  [20100/60000]
# loss: 0.006622  [30100/60000]
# loss: 0.005768  [40100/60000]
# loss: 0.006153  [50100/60000]
# Test Error: Avg loss: 0.005441
#
# Test Error: Avg loss: 0.005710
#
# Epoch 30
# -------------------------------
# loss: 0.006874  [  100/60000]
# loss: 0.005799  [10100/60000]
# loss: 0.005820  [20100/60000]
# loss: 0.006027  [30100/60000]
# loss: 0.005925  [40100/60000]
# loss: 0.005848  [50100/60000]
# Test Error: Avg loss: 0.005462
#
# Test Error: Avg loss: 0.005730
#
# Epoch 31
# -------------------------------
# loss: 0.005342  [  100/60000]
# loss: 0.005883  [10100/60000]
# loss: 0.006232  [20100/60000]
# loss: 0.005472  [30100/60000]
# loss: 0.005785  [40100/60000]
# loss: 0.005950  [50100/60000]
# Test Error: Avg loss: 0.005443
#
# Test Error: Avg loss: 0.005720
#
# Epoch 32
# -------------------------------
# loss: 0.005141  [  100/60000]
# loss: 0.005550  [10100/60000]
# loss: 0.006115  [20100/60000]
# loss: 0.006214  [30100/60000]
# loss: 0.005638  [40100/60000]
# loss: 0.006851  [50100/60000]
# Test Error: Avg loss: 0.005439
#
# Test Error: Avg loss: 0.005720
#
# Epoch 33
# -------------------------------
# loss: 0.005980  [  100/60000]
# loss: 0.006035  [10100/60000]
# loss: 0.005949  [20100/60000]
# loss: 0.005800  [30100/60000]
# loss: 0.005679  [40100/60000]
# loss: 0.006737  [50100/60000]
# Test Error: Avg loss: 0.005372
#
# Test Error: Avg loss: 0.005653
#
# Epoch 34
# -------------------------------
# loss: 0.006346  [  100/60000]
# loss: 0.006068  [10100/60000]
# loss: 0.005804  [20100/60000]
# loss: 0.006077  [30100/60000]
# loss: 0.006538  [40100/60000]
# loss: 0.006146  [50100/60000]
# Test Error: Avg loss: 0.005357
#
# Test Error: Avg loss: 0.005641
#
# Epoch 35
# -------------------------------
# loss: 0.005527  [  100/60000]
# loss: 0.005425  [10100/60000]
# loss: 0.006484  [20100/60000]
# loss: 0.005927  [30100/60000]
# loss: 0.006192  [40100/60000]
# loss: 0.006320  [50100/60000]
# Test Error: Avg loss: 0.005349
#
# Test Error: Avg loss: 0.005638
#
# Epoch 36
# -------------------------------
# loss: 0.005901  [  100/60000]
# loss: 0.005806  [10100/60000]
# loss: 0.006126  [20100/60000]
# loss: 0.005422  [30100/60000]
# loss: 0.006193  [40100/60000]
# loss: 0.005375  [50100/60000]
# Test Error: Avg loss: 0.005385
#
# Test Error: Avg loss: 0.005677
#
# Epoch 37
# -------------------------------
# loss: 0.005920  [  100/60000]
# loss: 0.005489  [10100/60000]
# loss: 0.004936  [20100/60000]
# loss: 0.005242  [30100/60000]
# loss: 0.006271  [40100/60000]
# loss: 0.005912  [50100/60000]
# Test Error: Avg loss: 0.005347
#
# Test Error: Avg loss: 0.005634
#
# Epoch 38
# -------------------------------
# loss: 0.005890  [  100/60000]
# loss: 0.005848  [10100/60000]
# loss: 0.005754  [20100/60000]
# loss: 0.005950  [30100/60000]
# loss: 0.006526  [40100/60000]
# loss: 0.005418  [50100/60000]
# Test Error: Avg loss: 0.005319
#
# Test Error: Avg loss: 0.005612
#
# Epoch 39
# -------------------------------
# loss: 0.005400  [  100/60000]
# loss: 0.005201  [10100/60000]
# loss: 0.006379  [20100/60000]
# loss: 0.006118  [30100/60000]
# loss: 0.005659  [40100/60000]
# loss: 0.005754  [50100/60000]
# Test Error: Avg loss: 0.005286
#
# Test Error: Avg loss: 0.005581
#
# Epoch 40
# -------------------------------
# loss: 0.005594  [  100/60000]
# loss: 0.005991  [10100/60000]
# loss: 0.005965  [20100/60000]
# loss: 0.005849  [30100/60000]
# loss: 0.006085  [40100/60000]
# loss: 0.005511  [50100/60000]
# Test Error: Avg loss: 0.005259
#
# Test Error: Avg loss: 0.005557
#
# Done!

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='tab:blue', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='tab:green', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pre_trained_autoencoder.eval()

idxs = [0, 1, 21+6]

fig = plt.figure(figsize=(9, 5))

with torch.no_grad():
    for i, idx in enumerate(idxs):
        image, label = train_set_orig[idx]

        # ---------- Original ----------
        plt.subplot(2, 3, i+1)
        plt.imshow(image.squeeze(), cmap='gray')
        plt.title(class_names[label])
        plt.axis('off')

        # ---------- Reconstrucción ----------
        input_img = image.unsqueeze(0).to(device)
        output_img = pre_trained_autoencoder(input_img)
        output_img = output_img.cpu().squeeze()

        plt.subplot(2, 3, i+4)
        plt.imshow(output_img, cmap='gray')
        plt.axis('off')

# Títulos de filas
fig.text(0.5, 0.93, "Imágenes Originales", ha='center', fontsize=20)
fig.text(0.5, 0.47, "Reconstrucciones", ha='center', fontsize=20)

fig.subplots_adjust(top=0.85, hspace=0.35)
plt.show()

# %% [markdown]
# ## ***a) Cantidad de filtros***
#
# - Pasamos de (8,16) a (32,64)

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_a = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=32, filter_num2=64, use_bn=True).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_a.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_a, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_a, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_a, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='tab:crimson', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='tab:green', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ ***b) Modificar kernels/stride/padding***
#
# ks1=5
# ks2=5
#
# pad1=2
# pad2=2
#
# str1=1
# str2=1 (queda igual)
#
#
# ks3=2
# ks4=5
#
# pad3=1
# pad4=1 (si no da error de dimensiones)
# _____
# ks3=3
# ks4=5

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_b = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=8, filter_num2=16, ks1=5, ks2=5, pad1=2,
                                                     pad2=2, str1=1, str2=1, ks3=2, ks4=5, pad3=1, pad4=1, use_bn=True).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_b.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_b, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_b, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_b, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.168434  [  100/60000]
# loss: 0.029248  [10100/60000]
# loss: 0.020634  [20100/60000]
# loss: 0.020164  [30100/60000]
# loss: 0.018547  [40100/60000]
# loss: 0.016216  [50100/60000]
# Test Error: Avg loss: 0.014985
#
# Test Error: Avg loss: 0.015097
#
# Epoch 2
# -------------------------------
# loss: 0.016633  [  100/60000]
# loss: 0.014674  [10100/60000]
# loss: 0.013197  [20100/60000]
# loss: 0.012938  [30100/60000]
# loss: 0.013628  [40100/60000]
# loss: 0.011612  [50100/60000]
# Test Error: Avg loss: 0.011543
#
# Test Error: Avg loss: 0.011666
#
# Epoch 3
# -------------------------------
# loss: 0.012748  [  100/60000]
# loss: 0.010509  [10100/60000]
# loss: 0.012503  [20100/60000]
# loss: 0.012177  [30100/60000]
# loss: 0.012094  [40100/60000]
# loss: 0.011149  [50100/60000]
# Test Error: Avg loss: 0.010168
#
# Test Error: Avg loss: 0.010291
#
# Epoch 4
# -------------------------------
# loss: 0.011200  [  100/60000]
# loss: 0.011176  [10100/60000]
# loss: 0.009752  [20100/60000]
# loss: 0.010117  [30100/60000]
# loss: 0.009737  [40100/60000]
# loss: 0.010503  [50100/60000]
# Test Error: Avg loss: 0.009352
#
# Test Error: Avg loss: 0.009473
#
# Epoch 5
# -------------------------------
# loss: 0.010105  [  100/60000]
# loss: 0.008378  [10100/60000]
# loss: 0.009112  [20100/60000]
# loss: 0.007990  [30100/60000]
# loss: 0.010041  [40100/60000]
# loss: 0.010586  [50100/60000]
# Test Error: Avg loss: 0.008672
#
# Test Error: Avg loss: 0.008802
#
# Epoch 6
# -------------------------------
# loss: 0.008880  [  100/60000]
# loss: 0.009458  [10100/60000]
# loss: 0.008607  [20100/60000]
# loss: 0.010818  [30100/60000]
# loss: 0.007893  [40100/60000]
# loss: 0.010236  [50100/60000]
# Test Error: Avg loss: 0.008388
#
# Test Error: Avg loss: 0.008521
#
# Epoch 7
# -------------------------------
# loss: 0.009492  [  100/60000]
# loss: 0.008974  [10100/60000]
# loss: 0.008546  [20100/60000]
# loss: 0.009338  [30100/60000]
# loss: 0.008960  [40100/60000]
# loss: 0.008849  [50100/60000]
# Test Error: Avg loss: 0.008008
#
# Test Error: Avg loss: 0.008147
#
# Epoch 8
# -------------------------------
# loss: 0.008203  [  100/60000]
# loss: 0.009362  [10100/60000]
# loss: 0.008556  [20100/60000]
# loss: 0.007234  [30100/60000]
# loss: 0.008615  [40100/60000]
# loss: 0.007612  [50100/60000]
# Test Error: Avg loss: 0.007810
#
# Test Error: Avg loss: 0.007956
#
# Epoch 9
# -------------------------------
# loss: 0.008575  [  100/60000]
# loss: 0.007862  [10100/60000]
# loss: 0.008242  [20100/60000]
# loss: 0.007774  [30100/60000]
# loss: 0.009185  [40100/60000]
# loss: 0.008587  [50100/60000]
# Test Error: Avg loss: 0.007671
#
# Test Error: Avg loss: 0.007818
#
# Epoch 10
# -------------------------------
# loss: 0.008417  [  100/60000]
# loss: 0.008260  [10100/60000]
# loss: 0.008536  [20100/60000]
# loss: 0.008392  [30100/60000]
# loss: 0.008897  [40100/60000]
# loss: 0.007873  [50100/60000]
# Test Error: Avg loss: 0.007517
#
# Test Error: Avg loss: 0.007667
#
# Epoch 11
# -------------------------------
# loss: 0.008023  [  100/60000]
# loss: 0.008113  [10100/60000]
# loss: 0.007129  [20100/60000]
# loss: 0.007787  [30100/60000]
# loss: 0.007930  [40100/60000]
# loss: 0.008237  [50100/60000]
# Test Error: Avg loss: 0.007508
#
# Test Error: Avg loss: 0.007667
#
# Epoch 12
# -------------------------------
# loss: 0.009138  [  100/60000]
# loss: 0.007461  [10100/60000]
# loss: 0.007451  [20100/60000]
# loss: 0.008351  [30100/60000]
# loss: 0.007143  [40100/60000]
# loss: 0.007893  [50100/60000]
# Test Error: Avg loss: 0.007248
#
# Test Error: Avg loss: 0.007405
#
# Epoch 13
# -------------------------------
# loss: 0.007421  [  100/60000]
# loss: 0.007657  [10100/60000]
# loss: 0.008454  [20100/60000]
# loss: 0.008052  [30100/60000]
# loss: 0.008345  [40100/60000]
# loss: 0.008636  [50100/60000]
# Test Error: Avg loss: 0.007211
#
# Test Error: Avg loss: 0.007373
#
# Epoch 14
# -------------------------------
# loss: 0.007502  [  100/60000]
# loss: 0.007729  [10100/60000]
# loss: 0.007383  [20100/60000]
# loss: 0.007549  [30100/60000]
# loss: 0.007989  [40100/60000]
# loss: 0.007913  [50100/60000]
# Test Error: Avg loss: 0.007090
#
# Test Error: Avg loss: 0.007252
#
# Epoch 15
# -------------------------------
# loss: 0.008220  [  100/60000]
# loss: 0.007772  [10100/60000]
# loss: 0.008064  [20100/60000]
# loss: 0.008019  [30100/60000]
# loss: 0.008389  [40100/60000]
# loss: 0.008660  [50100/60000]
# Test Error: Avg loss: 0.006947
#
# Test Error: Avg loss: 0.007115
#
# Epoch 16
# -------------------------------
# loss: 0.008066  [  100/60000]
# loss: 0.007722  [10100/60000]
# loss: 0.007680  [20100/60000]
# loss: 0.007769  [30100/60000]
# loss: 0.007986  [40100/60000]
# loss: 0.007580  [50100/60000]
# Test Error: Avg loss: 0.006886
#
# Test Error: Avg loss: 0.007064
#
# Epoch 17
# -------------------------------
# loss: 0.007908  [  100/60000]
# loss: 0.008859  [10100/60000]
# loss: 0.007232  [20100/60000]
# loss: 0.007491  [30100/60000]
# loss: 0.007202  [40100/60000]
# loss: 0.008135  [50100/60000]
# Test Error: Avg loss: 0.006879
#
# Test Error: Avg loss: 0.007054
#
# Epoch 18
# -------------------------------
# loss: 0.008721  [  100/60000]
# loss: 0.007695  [10100/60000]
# loss: 0.006779  [20100/60000]
# loss: 0.007369  [30100/60000]
# loss: 0.007208  [40100/60000]
# loss: 0.007112  [50100/60000]
# Test Error: Avg loss: 0.006765
#
# Test Error: Avg loss: 0.006944
#
# Epoch 19
# -------------------------------
# loss: 0.007177  [  100/60000]
# loss: 0.006756  [10100/60000]
# loss: 0.007779  [20100/60000]
# loss: 0.007457  [30100/60000]
# loss: 0.006232  [40100/60000]
# loss: 0.007697  [50100/60000]
# Test Error: Avg loss: 0.006705
#
# Test Error: Avg loss: 0.006889
#
# Epoch 20
# -------------------------------
# loss: 0.007919  [  100/60000]
# loss: 0.007972  [10100/60000]
# loss: 0.006987  [20100/60000]
# loss: 0.008022  [30100/60000]
# loss: 0.007760  [40100/60000]
# loss: 0.007218  [50100/60000]
# Test Error: Avg loss: 0.006835
#
# Test Error: Avg loss: 0.007019
#
# Epoch 21
# -------------------------------
# loss: 0.006869  [  100/60000]
# loss: 0.006306  [10100/60000]
# loss: 0.007096  [20100/60000]
# loss: 0.006932  [30100/60000]
# loss: 0.007971  [40100/60000]
# loss: 0.008212  [50100/60000]
# Test Error: Avg loss: 0.006647
#
# Test Error: Avg loss: 0.006833
#
# Epoch 22
# -------------------------------
# loss: 0.007002  [  100/60000]
# loss: 0.007181  [10100/60000]
# loss: 0.007710  [20100/60000]
# loss: 0.006814  [30100/60000]
# loss: 0.006864  [40100/60000]
# loss: 0.006903  [50100/60000]
# Test Error: Avg loss: 0.006645
#
# Test Error: Avg loss: 0.006835
#
# Epoch 23
# -------------------------------
# loss: 0.007112  [  100/60000]
# loss: 0.007057  [10100/60000]
# loss: 0.006330  [20100/60000]
# loss: 0.007725  [30100/60000]
# loss: 0.007372  [40100/60000]
# loss: 0.008225  [50100/60000]
# Test Error: Avg loss: 0.006562
#
# Test Error: Avg loss: 0.006753
#
# Epoch 24
# -------------------------------
# loss: 0.007584  [  100/60000]
# loss: 0.006832  [10100/60000]
# loss: 0.007434  [20100/60000]
# loss: 0.007643  [30100/60000]
# loss: 0.006821  [40100/60000]
# loss: 0.008413  [50100/60000]
# Test Error: Avg loss: 0.006566
#
# Test Error: Avg loss: 0.006758
#
# Epoch 25
# -------------------------------
# loss: 0.007482  [  100/60000]
# loss: 0.005992  [10100/60000]
# loss: 0.006998  [20100/60000]
# loss: 0.006513  [30100/60000]
# loss: 0.006605  [40100/60000]
# loss: 0.006514  [50100/60000]
# Test Error: Avg loss: 0.006542
#
# Test Error: Avg loss: 0.006735
#
# Epoch 26
# -------------------------------
# loss: 0.007051  [  100/60000]
# loss: 0.007106  [10100/60000]
# loss: 0.007233  [20100/60000]
# loss: 0.007643  [30100/60000]
# loss: 0.007130  [40100/60000]
# loss: 0.007923  [50100/60000]
# Test Error: Avg loss: 0.006473
#
# Test Error: Avg loss: 0.006671
#
# Epoch 27
# -------------------------------
# loss: 0.007099  [  100/60000]
# loss: 0.007314  [10100/60000]
# loss: 0.006964  [20100/60000]
# loss: 0.007839  [30100/60000]
# loss: 0.006396  [40100/60000]
# loss: 0.007112  [50100/60000]
# Test Error: Avg loss: 0.006517
#
# Test Error: Avg loss: 0.006713
#
# Epoch 28
# -------------------------------
# loss: 0.007090  [  100/60000]
# loss: 0.006346  [10100/60000]
# loss: 0.006546  [20100/60000]
# loss: 0.007836  [30100/60000]
# loss: 0.005998  [40100/60000]
# loss: 0.007466  [50100/60000]
# Test Error: Avg loss: 0.006438
#
# Test Error: Avg loss: 0.006640
#
# Epoch 29
# -------------------------------
# loss: 0.006615  [  100/60000]
# loss: 0.006670  [10100/60000]
# loss: 0.007489  [20100/60000]
# loss: 0.007744  [30100/60000]
# loss: 0.006790  [40100/60000]
# loss: 0.006879  [50100/60000]
# Test Error: Avg loss: 0.006493
#
# Test Error: Avg loss: 0.006694
#
# Epoch 30
# -------------------------------
# loss: 0.006503  [  100/60000]
# loss: 0.007009  [10100/60000]
# loss: 0.007212  [20100/60000]
# loss: 0.007443  [30100/60000]
# loss: 0.007722  [40100/60000]
# loss: 0.007399  [50100/60000]
# Test Error: Avg loss: 0.006451
#
# Test Error: Avg loss: 0.006656
#
# Done!

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='crimson', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ***c) Quitar bottleneck***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_c = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=8, filter_num2=16, use_bn=False).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_c.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_c, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_c, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_c, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='skyblue', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='coral', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ ***d) Tasa de aprendizaje***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_d = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=8, filter_num2=16, use_bn=True).to(device)

# -------- Optimizer --------
learning_rate = 1e-4
optimizer = torch.optim.Adam(pre_trained_autoencoder_d.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_d, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_d, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_d, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.163494  [  100/60000]
# loss: 0.102674  [10100/60000]
# loss: 0.060865  [20100/60000]
# loss: 0.043316  [30100/60000]
# loss: 0.038901  [40100/60000]
# loss: 0.036352  [50100/60000]
# Test Error: Avg loss: 0.032451
#
# Test Error: Avg loss: 0.032445
#
# Epoch 2
# -------------------------------
# loss: 0.031041  [  100/60000]
# loss: 0.030041  [10100/60000]
# loss: 0.027174  [20100/60000]
# loss: 0.029361  [30100/60000]
# loss: 0.027157  [40100/60000]
# loss: 0.027241  [50100/60000]
# Test Error: Avg loss: 0.025597
#
# Test Error: Avg loss: 0.025650
#
# Epoch 3
# -------------------------------
# loss: 0.028238  [  100/60000]
# loss: 0.024650  [10100/60000]
# loss: 0.027090  [20100/60000]
# loss: 0.022390  [30100/60000]
# loss: 0.022941  [40100/60000]
# loss: 0.025272  [50100/60000]
# Test Error: Avg loss: 0.021959
#
# Test Error: Avg loss: 0.022031
#
# Epoch 4
# -------------------------------
# loss: 0.021752  [  100/60000]
# loss: 0.024403  [10100/60000]
# loss: 0.021908  [20100/60000]
# loss: 0.021022  [30100/60000]
# loss: 0.021729  [40100/60000]
# loss: 0.020905  [50100/60000]
# Test Error: Avg loss: 0.019675
#
# Test Error: Avg loss: 0.019748
#
# Epoch 5
# -------------------------------
# loss: 0.020818  [  100/60000]
# loss: 0.018786  [10100/60000]
# loss: 0.020318  [20100/60000]
# loss: 0.018489  [30100/60000]
# loss: 0.019439  [40100/60000]
# loss: 0.021022  [50100/60000]
# Test Error: Avg loss: 0.018246
#
# Test Error: Avg loss: 0.018321
#
# Epoch 6
# -------------------------------
# loss: 0.018837  [  100/60000]
# loss: 0.018102  [10100/60000]
# loss: 0.019954  [20100/60000]
# loss: 0.019775  [30100/60000]
# loss: 0.019241  [40100/60000]
# loss: 0.017909  [50100/60000]
# Test Error: Avg loss: 0.017213
#
# Test Error: Avg loss: 0.017286
#
# Epoch 7
# -------------------------------
# loss: 0.017562  [  100/60000]
# loss: 0.018172  [10100/60000]
# loss: 0.018970  [20100/60000]
# loss: 0.016195  [30100/60000]
# loss: 0.017301  [40100/60000]
# loss: 0.016212  [50100/60000]
# Test Error: Avg loss: 0.016161
#
# Test Error: Avg loss: 0.016241
#
# Epoch 8
# -------------------------------
# loss: 0.017906  [  100/60000]
# loss: 0.016405  [10100/60000]
# loss: 0.017273  [20100/60000]
# loss: 0.016204  [30100/60000]
# loss: 0.016827  [40100/60000]
# loss: 0.016472  [50100/60000]
# Test Error: Avg loss: 0.015367
#
# Test Error: Avg loss: 0.015441
#
# Epoch 9
# -------------------------------
# loss: 0.017522  [  100/60000]
# loss: 0.016706  [10100/60000]
# loss: 0.015658  [20100/60000]
# loss: 0.014896  [30100/60000]
# loss: 0.016152  [40100/60000]
# loss: 0.017434  [50100/60000]
# Test Error: Avg loss: 0.014728
#
# Test Error: Avg loss: 0.014803
#
# Epoch 10
# -------------------------------
# loss: 0.015526  [  100/60000]
# loss: 0.015617  [10100/60000]
# loss: 0.017824  [20100/60000]
# loss: 0.014663  [30100/60000]
# loss: 0.015754  [40100/60000]
# loss: 0.014485  [50100/60000]
# Test Error: Avg loss: 0.014162
#
# Test Error: Avg loss: 0.014242
#
# Epoch 11
# -------------------------------
# loss: 0.016527  [  100/60000]
# loss: 0.014714  [10100/60000]
# loss: 0.016316  [20100/60000]
# loss: 0.013398  [30100/60000]
# loss: 0.014167  [40100/60000]
# loss: 0.014634  [50100/60000]
# Test Error: Avg loss: 0.013633
#
# Test Error: Avg loss: 0.013711
#
# Epoch 12
# -------------------------------
# loss: 0.015338  [  100/60000]
# loss: 0.014373  [10100/60000]
# loss: 0.014427  [20100/60000]
# loss: 0.015603  [30100/60000]
# loss: 0.013412  [40100/60000]
# loss: 0.013952  [50100/60000]
# Test Error: Avg loss: 0.013109
#
# Test Error: Avg loss: 0.013194
#
# Epoch 13
# -------------------------------
# loss: 0.012607  [  100/60000]
# loss: 0.014291  [10100/60000]
# loss: 0.013585  [20100/60000]
# loss: 0.013624  [30100/60000]
# loss: 0.013348  [40100/60000]
# loss: 0.014088  [50100/60000]
# Test Error: Avg loss: 0.012660
#
# Test Error: Avg loss: 0.012744
#
# Epoch 14
# -------------------------------
# loss: 0.012815  [  100/60000]
# loss: 0.013523  [10100/60000]
# loss: 0.013707  [20100/60000]
# loss: 0.013844  [30100/60000]
# loss: 0.014190  [40100/60000]
# loss: 0.012356  [50100/60000]
# Test Error: Avg loss: 0.012300
#
# Test Error: Avg loss: 0.012383
#
# Epoch 15
# -------------------------------
# loss: 0.013712  [  100/60000]
# loss: 0.011919  [10100/60000]
# loss: 0.013678  [20100/60000]
# loss: 0.013305  [30100/60000]
# loss: 0.013168  [40100/60000]
# loss: 0.012960  [50100/60000]
# Test Error: Avg loss: 0.011963
#
# Test Error: Avg loss: 0.012045
#
# Epoch 16
# -------------------------------
# loss: 0.012782  [  100/60000]
# loss: 0.012547  [10100/60000]
# loss: 0.013617  [20100/60000]
# loss: 0.013478  [30100/60000]
# loss: 0.013468  [40100/60000]
# loss: 0.012355  [50100/60000]
# Test Error: Avg loss: 0.011663
#
# Test Error: Avg loss: 0.011751
#
# Epoch 17
# -------------------------------
# loss: 0.013506  [  100/60000]
# loss: 0.011716  [10100/60000]
# loss: 0.013194  [20100/60000]
# loss: 0.012894  [30100/60000]
# loss: 0.011637  [40100/60000]
# loss: 0.011562  [50100/60000]
# Test Error: Avg loss: 0.011334
#
# Test Error: Avg loss: 0.011420
#
# Epoch 18
# -------------------------------
# loss: 0.011970  [  100/60000]
# loss: 0.013326  [10100/60000]
# loss: 0.012926  [20100/60000]
# loss: 0.013182  [30100/60000]
# loss: 0.012917  [40100/60000]
# loss: 0.012376  [50100/60000]
# Test Error: Avg loss: 0.011061
#
# Test Error: Avg loss: 0.011152
#
# Epoch 19
# -------------------------------
# loss: 0.012837  [  100/60000]
# loss: 0.010719  [10100/60000]
# loss: 0.011441  [20100/60000]
# loss: 0.011738  [30100/60000]
# loss: 0.012150  [40100/60000]
# loss: 0.011575  [50100/60000]
# Test Error: Avg loss: 0.010787
#
# Test Error: Avg loss: 0.010881
#
# Epoch 20
# -------------------------------
# loss: 0.011780  [  100/60000]
# loss: 0.011689  [10100/60000]
# loss: 0.012638  [20100/60000]
# loss: 0.011420  [30100/60000]
# loss: 0.012212  [40100/60000]
# loss: 0.010243  [50100/60000]
# Test Error: Avg loss: 0.010548
#
# Test Error: Avg loss: 0.010646
#
# Epoch 21
# -------------------------------
# loss: 0.011126  [  100/60000]
# loss: 0.011870  [10100/60000]
# loss: 0.012222  [20100/60000]
# loss: 0.011051  [30100/60000]
# loss: 0.012634  [40100/60000]
# loss: 0.011451  [50100/60000]
# Test Error: Avg loss: 0.010338
#
# Test Error: Avg loss: 0.010436
#
# Epoch 22
# -------------------------------
# loss: 0.010825  [  100/60000]
# loss: 0.011988  [10100/60000]
# loss: 0.010959  [20100/60000]
# loss: 0.011315  [30100/60000]
# loss: 0.010986  [40100/60000]
# loss: 0.010416  [50100/60000]
# Test Error: Avg loss: 0.010147
#
# Test Error: Avg loss: 0.010247
#
# Epoch 23
# -------------------------------
# loss: 0.011215  [  100/60000]
# loss: 0.011326  [10100/60000]
# loss: 0.010459  [20100/60000]
# loss: 0.010395  [30100/60000]
# loss: 0.010570  [40100/60000]
# loss: 0.010766  [50100/60000]
# Test Error: Avg loss: 0.009951
#
# Test Error: Avg loss: 0.010054
#
# Epoch 24
# -------------------------------
# loss: 0.010769  [  100/60000]
# loss: 0.010413  [10100/60000]
# loss: 0.011557  [20100/60000]
# loss: 0.011089  [30100/60000]
# loss: 0.011881  [40100/60000]
# loss: 0.011113  [50100/60000]
# Test Error: Avg loss: 0.009764
#
# Test Error: Avg loss: 0.009867
#
# Epoch 25
# -------------------------------
# loss: 0.010683  [  100/60000]
# loss: 0.011144  [10100/60000]
# loss: 0.010891  [20100/60000]
# loss: 0.011512  [30100/60000]
# loss: 0.010099  [40100/60000]
# loss: 0.010934  [50100/60000]
# Test Error: Avg loss: 0.009603
#
# Test Error: Avg loss: 0.009708
#
# Epoch 26
# -------------------------------
# loss: 0.011467  [  100/60000]
# loss: 0.010513  [10100/60000]
# loss: 0.010470  [20100/60000]
# loss: 0.010984  [30100/60000]
# loss: 0.010659  [40100/60000]
# loss: 0.009467  [50100/60000]
# Test Error: Avg loss: 0.009489
#
# Test Error: Avg loss: 0.009594
#
# Epoch 27
# -------------------------------
# loss: 0.010529  [  100/60000]
# loss: 0.010860  [10100/60000]
# loss: 0.009458  [20100/60000]
# loss: 0.010421  [30100/60000]
# loss: 0.009493  [40100/60000]
# loss: 0.010074  [50100/60000]
# Test Error: Avg loss: 0.009321
#
# Test Error: Avg loss: 0.009427
#
# Epoch 28
# -------------------------------
# loss: 0.009472  [  100/60000]
# loss: 0.010795  [10100/60000]
# loss: 0.009679  [20100/60000]
# loss: 0.009532  [30100/60000]
# loss: 0.010755  [40100/60000]
# loss: 0.009552  [50100/60000]
# Test Error: Avg loss: 0.009207
#
# Test Error: Avg loss: 0.009315
#
# Epoch 29
# -------------------------------
# loss: 0.010810  [  100/60000]
# loss: 0.009842  [10100/60000]
# loss: 0.009718  [20100/60000]
# loss: 0.010252  [30100/60000]
# loss: 0.009624  [40100/60000]
# loss: 0.012130  [50100/60000]
# Test Error: Avg loss: 0.009083
#
# Test Error: Avg loss: 0.009190
#
# Epoch 30
# -------------------------------
# loss: 0.010920  [  100/60000]
# loss: 0.010008  [10100/60000]
# loss: 0.009603  [20100/60000]
# loss: 0.010493  [30100/60000]
# loss: 0.010288  [40100/60000]
# loss: 0.008907  [50100/60000]
# Test Error: Avg loss: 0.008965
#
# Test Error: Avg loss: 0.009072
#
# Done!

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='gold', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='olive', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ***e) Dropout***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_e = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=8, filter_num2=16, use_bn=True).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_e.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_e, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_e, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_e, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='fuchsia', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='limegreen', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ ***f) Agregar capa lineal antes del bottleneck***
#
# Progressive compression

# %%
# 4.1)
class AutoencoderConvolutional_mod(nn.Module):
    """
    Autoencoder convolucional profundo para imágenes Fashion-MNIST (1x28x28),
    compuesto por un módulo codificador convolucional, un cuello de botella
    opcional completamente conectado y un decodificador convolucional transpuesto.

    Parameters
    ----------
    p1 : float, optional
        Probabilidad de dropout aplicada al final del codificador convolucional.
        Controla el nivel de regularización (default = 0.2).

    p2 : float, optional
        Probabilidad de dropout aplicada en el cuello de botella completamente conectado.
        Permite regularizar el espacio latente. Por defecto no se aplica dropout (default = 0.0).

    n : int, optional
        Dimensión del espacio latente en el cuello de botella fully-connected.
        Determina el grado de compresión de la representación (default = 128).

    filter_num1 : int, optional
        Número de filtros de la primera convolución del encoder.
        Define la profundidad inicial del mapa de características
        (default = 8).

    filter_num2 : int, optional
        Número de filtros de la segunda convolución del encoder.
        Aumenta la capacidad representacional del modelo antes del pooling
        (default = 16).

    ks1 : int, optional
        Tamaño del kernel de la primera convolución del encoder (default = 3).

    ks2 : int, optional
        Tamaño del kernel de la segunda convolución del encoder (default = 3).

    ks3 : int, optional
        Tamaño del kernel de la primera convolución transpuesta del decoder (default = 2).

    ks4 : int, optional
        Tamaño del kernel de la segunda convolución transpuesta del decoder (default = 5).

    str1 : int, optional
        Stride de la primera convolución del encoder (default = 1).

    str2 : int, optional
        Stride de la segunda convolución del encoder (default = 1).

    str3 : int, optional
        Stride de la primera convolución transpuesta del decoder (default = 2).

    str4 : int, optional
        Stride de la segunda convolución transpuesta del decoder (default = 1).

    pad1 : int, optional
        Padding de la primera convolución del encoder (default = 0).

    pad2 : int, optional
        Padding de la segunda convolución del encoder (default = 0).

    pad3 : int, optional
        Padding de la primera convolución transpuesta del decoder (default = 0).

    pad4 : int, optional
        Padding de la segunda convolución transpuesta del decoder (default = 0).

    dil1 : int, optional
        Dilatación de la primera convolución del encoder (default = 1).

    dil2 : int, optional
        Dilatación de la segunda convolución del encoder (default = 1).

    dil3 : int, optional
        Dilatación de la primera convolución transpuesta del decoder (default = 1).

    dil4 : int, optional
        Dilatación de la segunda convolución transpuesta del decoder (default = 1).

    pool_size : tuple of int, optional
        Tamaño del max-pooling aplicado luego de la convolución del encoder.
        Reduce la resolución espacial de los mapas de características
        (default = (2, 2)).

    use_bn : bool, optional
        Indica si se utiliza un cuello de botella lineal completamente conectado.
        Si True, se incluye una capa fully-connected que comprime la representación
        a dimensión n. Si False, se omite el cuello de botella y se mantiene la
        representación convolucional plana (default = True).
    """
    def __init__(self, p1=0.2, p2=0.0, n=128,
                filter_num1=8, filter_num2=16,
                ks1=3, ks2=3, ks3=2, ks4=5,
                str1=1, str2=1, str3=2, str4=1,
                pad1=0, pad2=0, pad3=0, pad4=0,
                dil1=1, dil2=1, dil3=1, dil4=1,
                pool_size=(2,2), use_bn = True):
        super().__init__()

        conv1_out = ((28 + 2*pad1 - dil1*(ks1 - 1) - 1) // str1) + 1
        conv2_out = ((conv1_out + 2*pad2 - dil2*(ks2 - 1) - 1) // str2) + 1

        h_after_pool = conv2_out // pool_size[0]
        w_after_pool = conv2_out // pool_size[1]

        # conv_trans1_out = ((h_after_pool - 1)*str3 - 2*pad3 + dil3*(ks3 - 1) + 1)
        # conv_trans2_out = ((conv_trans1_out - 1)*str4 - 2*pad4 + dil4*(ks4 - 1) + 1)


        self.flat_size = filter_num2 * h_after_pool * w_after_pool

        # -------- Encoder --------
        self.encoder = nn.Sequential(
            nn.Conv2d(1, filter_num1, kernel_size=ks1, stride=str1, padding=pad1, dilation=dil1),  # (1,28,28) -> (filter_num1,conv1_out,conv1_out)
            nn.ReLU(),
            nn.Conv2d(filter_num1, filter_num2, kernel_size=ks2, stride=str2, padding=pad2, dilation=dil2), # (filter_num1,conv1_out,conv1_out) -> (filter_num2,conv2_out,conv2_out)
            nn.ReLU(),
            nn.MaxPool2d(pool_size),             # (filter_num2,h_after_pool,w_after_pool)
            nn.Dropout(p1)
        )

        # -------- Bottleneck MODIFIED --------
        if use_bn:
            self.bottleneck = nn.Sequential(
                nn.Flatten(),                     # (filter_num2,h_after_pool,w_after_pool) -> (flat_size)
                nn.Linear(self.flat_size, 256),   # flat_size -> 256
                nn.ReLU(),
                nn.Linear(256, n),                # 256 -> n
                nn.ReLU(),
                nn.Linear(n, 256),                # n -> 256
                nn.ReLU(),
                nn.Linear(256, self.flat_size),   # 256 -> flat_size
                nn.ReLU()
            )
        else:
            self.bottleneck = nn.Sequential(
                nn.Flatten(),
                nn.Identity()
            )

        # -------- Decoder --------
        self.decoder = nn.Sequential(
            nn.Unflatten(1, (filter_num2, h_after_pool, w_after_pool)),  # (flat_size) -> (filter_num2,h_after_pool,w_after_pool)
            nn.ConvTranspose2d(filter_num2, filter_num1, kernel_size=ks3, stride=str3, padding=pad3, dilation=dil3), # (filter_num2,h_after_pool,w_after_pool) -> (filter_num1,conv_trans1_out,conv_trans1_out)
            nn.ReLU(),
            nn.ConvTranspose2d(filter_num1, 1, kernel_size=ks4, stride=str4, padding=pad4, dilation=dil4), # (filter_num1,conv_trans2_out,conv_trans2_out) -> (1,28,28)
            nn.Sigmoid()                       # salida en [0,1]
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottleneck(x)
        x = self.decoder(x)
        return x

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128 # Misma cantidad de neuronas que de pixeles por imagen
pre_trained_autoencoder_f = AutoencoderConvolutional_mod(n=n, filter_num1=8, filter_num2=16).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_f.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_f, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_f, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_f, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.169797  [  100/60000]
# loss: 0.053650  [10100/60000]
# loss: 0.033725  [20100/60000]
# loss: 0.028303  [30100/60000]
# loss: 0.024827  [40100/60000]
# loss: 0.022795  [50100/60000]
# Test Error: Avg loss: 0.021007
#
# Test Error: Avg loss: 0.021108
#
# Epoch 2
# -------------------------------
# loss: 0.022227  [  100/60000]
# loss: 0.020231  [10100/60000]
# loss: 0.021348  [20100/60000]
# loss: 0.020089  [30100/60000]
# loss: 0.018186  [40100/60000]
# loss: 0.016843  [50100/60000]
# Test Error: Avg loss: 0.017066
#
# Test Error: Avg loss: 0.017175
#
# Epoch 3
# -------------------------------
# loss: 0.018172  [  100/60000]
# loss: 0.017265  [10100/60000]
# loss: 0.016291  [20100/60000]
# loss: 0.016684  [30100/60000]
# loss: 0.017202  [40100/60000]
# loss: 0.014413  [50100/60000]
# Test Error: Avg loss: 0.014895
#
# Test Error: Avg loss: 0.015022
#
# Epoch 4
# -------------------------------
# loss: 0.015582  [  100/60000]
# loss: 0.015095  [10100/60000]
# loss: 0.015036  [20100/60000]
# loss: 0.014351  [30100/60000]
# loss: 0.015082  [40100/60000]
# loss: 0.013470  [50100/60000]
# Test Error: Avg loss: 0.013374
#
# Test Error: Avg loss: 0.013508
#
# Epoch 5
# -------------------------------
# loss: 0.014155  [  100/60000]
# loss: 0.014787  [10100/60000]
# loss: 0.014524  [20100/60000]
# loss: 0.013487  [30100/60000]
# loss: 0.012751  [40100/60000]
# loss: 0.014438  [50100/60000]
# Test Error: Avg loss: 0.012590
#
# Test Error: Avg loss: 0.012743
#
# Epoch 6
# -------------------------------
# loss: 0.013498  [  100/60000]
# loss: 0.011851  [10100/60000]
# loss: 0.013286  [20100/60000]
# loss: 0.012041  [30100/60000]
# loss: 0.011946  [40100/60000]
# loss: 0.012711  [50100/60000]
# Test Error: Avg loss: 0.011824
#
# Test Error: Avg loss: 0.011993
#
# Epoch 7
# -------------------------------
# loss: 0.012042  [  100/60000]
# loss: 0.013012  [10100/60000]
# loss: 0.012281  [20100/60000]
# loss: 0.012473  [30100/60000]
# loss: 0.012090  [40100/60000]
# loss: 0.011768  [50100/60000]
# Test Error: Avg loss: 0.011247
#
# Test Error: Avg loss: 0.011416
#
# Epoch 8
# -------------------------------
# loss: 0.012117  [  100/60000]
# loss: 0.013622  [10100/60000]
# loss: 0.011794  [20100/60000]
# loss: 0.011529  [30100/60000]
# loss: 0.012284  [40100/60000]
# loss: 0.009919  [50100/60000]
# Test Error: Avg loss: 0.010909
#
# Test Error: Avg loss: 0.011089
#
# Epoch 9
# -------------------------------
# loss: 0.011163  [  100/60000]
# loss: 0.010559  [10100/60000]
# loss: 0.012537  [20100/60000]
# loss: 0.011840  [30100/60000]
# loss: 0.011290  [40100/60000]
# loss: 0.010588  [50100/60000]
# Test Error: Avg loss: 0.010486
#
# Test Error: Avg loss: 0.010676
#
# Epoch 10
# -------------------------------
# loss: 0.010732  [  100/60000]
# loss: 0.011167  [10100/60000]
# loss: 0.010807  [20100/60000]
# loss: 0.010050  [30100/60000]
# loss: 0.011126  [40100/60000]
# loss: 0.011000  [50100/60000]
# Test Error: Avg loss: 0.010262
#
# Test Error: Avg loss: 0.010454
#
# Epoch 11
# -------------------------------
# loss: 0.011034  [  100/60000]
# loss: 0.010246  [10100/60000]
# loss: 0.010127  [20100/60000]
# loss: 0.010141  [30100/60000]
# loss: 0.010468  [40100/60000]
# loss: 0.010591  [50100/60000]
# Test Error: Avg loss: 0.009943
#
# Test Error: Avg loss: 0.010147
#
# Epoch 12
# -------------------------------
# loss: 0.010266  [  100/60000]
# loss: 0.010880  [10100/60000]
# loss: 0.010289  [20100/60000]
# loss: 0.009312  [30100/60000]
# loss: 0.010941  [40100/60000]
# loss: 0.009204  [50100/60000]
# Test Error: Avg loss: 0.009751
#
# Test Error: Avg loss: 0.009956
#
# Epoch 13
# -------------------------------
# loss: 0.010978  [  100/60000]
# loss: 0.009833  [10100/60000]
# loss: 0.009700  [20100/60000]
# loss: 0.011378  [30100/60000]
# loss: 0.010913  [40100/60000]
# loss: 0.010164  [50100/60000]
# Test Error: Avg loss: 0.009537
#
# Test Error: Avg loss: 0.009742
#
# Epoch 14
# -------------------------------
# loss: 0.012025  [  100/60000]
# loss: 0.010276  [10100/60000]
# loss: 0.010402  [20100/60000]
# loss: 0.010060  [30100/60000]
# loss: 0.010354  [40100/60000]
# loss: 0.009565  [50100/60000]
# Test Error: Avg loss: 0.009309
#
# Test Error: Avg loss: 0.009516
#
# Epoch 15
# -------------------------------
# loss: 0.009269  [  100/60000]
# loss: 0.009222  [10100/60000]
# loss: 0.010598  [20100/60000]
# loss: 0.010105  [30100/60000]
# loss: 0.009556  [40100/60000]
# loss: 0.010286  [50100/60000]
# Test Error: Avg loss: 0.009085
#
# Test Error: Avg loss: 0.009296
#
# Epoch 16
# -------------------------------
# loss: 0.008982  [  100/60000]
# loss: 0.011208  [10100/60000]
# loss: 0.009950  [20100/60000]
# loss: 0.010360  [30100/60000]
# loss: 0.010722  [40100/60000]
# loss: 0.009500  [50100/60000]
# Test Error: Avg loss: 0.008890
#
# Test Error: Avg loss: 0.009115
#
# Epoch 17
# -------------------------------
# loss: 0.010429  [  100/60000]
# loss: 0.009618  [10100/60000]
# loss: 0.009928  [20100/60000]
# loss: 0.009261  [30100/60000]
# loss: 0.010327  [40100/60000]
# loss: 0.009142  [50100/60000]
# Test Error: Avg loss: 0.008892
#
# Test Error: Avg loss: 0.009114
#
# Epoch 18
# -------------------------------
# loss: 0.009282  [  100/60000]
# loss: 0.008419  [10100/60000]
# loss: 0.009790  [20100/60000]
# loss: 0.008346  [30100/60000]
# loss: 0.008548  [40100/60000]
# loss: 0.009228  [50100/60000]
# Test Error: Avg loss: 0.008611
#
# Test Error: Avg loss: 0.008836
#
# Epoch 19
# -------------------------------
# loss: 0.009014  [  100/60000]
# loss: 0.008857  [10100/60000]
# loss: 0.009667  [20100/60000]
# loss: 0.009005  [30100/60000]
# loss: 0.008884  [40100/60000]
# loss: 0.009632  [50100/60000]
# Test Error: Avg loss: 0.008446
#
# Test Error: Avg loss: 0.008674
#
# Epoch 20
# -------------------------------
# loss: 0.008408  [  100/60000]
# loss: 0.008563  [10100/60000]
# loss: 0.011091  [20100/60000]
# loss: 0.010325  [30100/60000]
# loss: 0.009504  [40100/60000]
# loss: 0.008916  [50100/60000]
# Test Error: Avg loss: 0.008508
#
# Test Error: Avg loss: 0.008739
#
# Epoch 21
# -------------------------------
# loss: 0.008733  [  100/60000]
# loss: 0.009152  [10100/60000]
# loss: 0.009117  [20100/60000]
# loss: 0.009725  [30100/60000]
# loss: 0.009484  [40100/60000]
# loss: 0.009874  [50100/60000]
# Test Error: Avg loss: 0.008350
#
# Test Error: Avg loss: 0.008586
#
# Epoch 22
# -------------------------------
# loss: 0.009417  [  100/60000]
# loss: 0.008996  [10100/60000]
# loss: 0.008576  [20100/60000]
# loss: 0.009089  [30100/60000]
# loss: 0.008603  [40100/60000]
# loss: 0.007950  [50100/60000]
# Test Error: Avg loss: 0.008184
#
# Test Error: Avg loss: 0.008414
#
# Epoch 23
# -------------------------------
# loss: 0.009047  [  100/60000]
# loss: 0.007793  [10100/60000]
# loss: 0.009742  [20100/60000]
# loss: 0.008926  [30100/60000]
# loss: 0.008829  [40100/60000]
# loss: 0.007908  [50100/60000]
# Test Error: Avg loss: 0.008194
#
# Test Error: Avg loss: 0.008426
#
# Epoch 24
# -------------------------------
# loss: 0.010626  [  100/60000]
# loss: 0.008927  [10100/60000]
# loss: 0.009475  [20100/60000]
# loss: 0.008668  [30100/60000]
# loss: 0.008256  [40100/60000]
# loss: 0.007910  [50100/60000]
# Test Error: Avg loss: 0.008025
#
# Test Error: Avg loss: 0.008266
#
# Epoch 25
# -------------------------------
# loss: 0.010552  [  100/60000]
# loss: 0.009696  [10100/60000]
# loss: 0.008284  [20100/60000]
# loss: 0.008666  [30100/60000]
# loss: 0.008402  [40100/60000]
# loss: 0.010738  [50100/60000]
# Test Error: Avg loss: 0.007968
#
# Test Error: Avg loss: 0.008209
#
# Epoch 26
# -------------------------------
# loss: 0.008095  [  100/60000]
# loss: 0.009043  [10100/60000]
# loss: 0.009710  [20100/60000]
# loss: 0.008582  [30100/60000]
# loss: 0.008993  [40100/60000]
# loss: 0.008651  [50100/60000]
# Test Error: Avg loss: 0.007835
#
# Test Error: Avg loss: 0.008082
#
# Epoch 27
# -------------------------------
# loss: 0.008297  [  100/60000]
# loss: 0.008513  [10100/60000]
# loss: 0.008484  [20100/60000]
# loss: 0.007561  [30100/60000]
# loss: 0.007419  [40100/60000]
# loss: 0.008852  [50100/60000]
# Test Error: Avg loss: 0.007815
#
# Test Error: Avg loss: 0.008062
#
# Epoch 28
# -------------------------------
# loss: 0.008415  [  100/60000]
# loss: 0.008377  [10100/60000]
# loss: 0.008479  [20100/60000]
# loss: 0.008594  [30100/60000]
# loss: 0.007952  [40100/60000]
# loss: 0.009333  [50100/60000]
# Test Error: Avg loss: 0.007751
#
# Test Error: Avg loss: 0.007995
#
# Epoch 29
# -------------------------------
# loss: 0.007952  [  100/60000]
# loss: 0.008650  [10100/60000]
# loss: 0.008396  [20100/60000]
# loss: 0.009273  [30100/60000]
# loss: 0.009563  [40100/60000]
# loss: 0.008733  [50100/60000]
# Test Error: Avg loss: 0.007770
#
# Test Error: Avg loss: 0.008017
#
# Epoch 30
# -------------------------------
# loss: 0.008326  [  100/60000]
# loss: 0.009346  [10100/60000]
# loss: 0.008111  [20100/60000]
# loss: 0.007452  [30100/60000]
# loss: 0.008239  [40100/60000]
# loss: 0.007942  [50100/60000]
# Test Error: Avg loss: 0.007724
#
# Test Error: Avg loss: 0.007975
#
# Done!

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='blueviolet', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='springgreen', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Más modif***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=64
pre_trained_autoencoder_f = AutoencoderConvolutional_mod(n=n, filter_num1=8, filter_num2=16).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_f.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %%
# OJO! El error en training es el que se imprime al finalizar todos los batches de la época.

EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, pre_trained_autoencoder_f, loss_fn, optimizer)
    train_loss = valid_loop_autoencoder(train_dataloader, pre_trained_autoencoder_f, loss_fn)
    valid_loss = valid_loop_autoencoder(valid_dataloader, pre_trained_autoencoder_f, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
print("Done!")

# %%
plt.title("Mean Square Error")
plt.xlabel("Épocas")
plt.ylabel("Error Promedio")
plt.plot(range(EPOCHS), train_loss_mean, color='blueviolet', label='Entrenamiento')
plt.plot(range(EPOCHS), valid_loss_mean, color='springgreen', label='Validación')
# plt.plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Entrenamiento
#
# Revisar que se esté utilizando el autoencoder correcto

# %% [markdown]
# ### ***Autoecoder seleccionado***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.MSELoss()

# -------- Model --------
n=128
pre_trained_autoencoder_c = AutoencoderConvolutional(n=n, p1=0.2, p2=0.0, filter_num1=8, filter_num2=16, use_bn=False).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(pre_trained_autoencoder_c.parameters(), lr=learning_rate)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []

# %% [markdown]
# ### ***Loop Clasificador***

# %%
def valid_loop_clasiffier(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    valid_loss, valid_correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)

            # Statistics
            valid_loss += loss_fn(pred, y).item()
            valid_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    valid_loss /= num_batches
    valid_correct /= size
    print(f"Test Error: \n Accuracy: {(100*valid_correct):>0.1f}%, Avg loss: {valid_loss:>8f} \n")

    return valid_loss, valid_correct

# %% [markdown]
# ### ***Elección de Clasificador***

# %% [markdown]
# #### ***Baseline***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier_b = Classifier(autoencoder=pre_trained_autoencoder_c, use_bn=False).to(device)

# Freeze encoder and bottleneck
for param in classifier_b.encoder.parameters():
    param.requires_grad = False

for param in classifier_b.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, classifier_b.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier0.named_parameters():
#     print(name, p.requires_grad)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier_b, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier_b, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier_b, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Setup baseline", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Error Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, 'o-', c='crimson', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, 'o-', c='olive', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ ***i) Nº de neuronas en capas ocultas***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier_i = Classifier(autoencoder=pre_trained_autoencoder_c, use_bn=False, n1= 512, n2=256).to(device)

# Freeze encoder and bottleneck
for param in classifier_i.encoder.parameters():
    param.requires_grad = False

for param in classifier_i.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, classifier_i.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier0.named_parameters():
#     print(name, p.requires_grad)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier_i, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier_i, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier_i, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.303451  [  100/60000]
# loss: 0.762445  [10100/60000]
# loss: 0.691485  [20100/60000]
# loss: 0.478658  [30100/60000]
# loss: 0.515452  [40100/60000]
# loss: 0.445986  [50100/60000]
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.479013
#
# Test Error:
#  Accuracy: 80.1%, Avg loss: 0.502077
#
# Epoch 2
# -------------------------------
# loss: 0.501435  [  100/60000]
# loss: 0.773680  [10100/60000]
# loss: 0.414692  [20100/60000]
# loss: 0.557870  [30100/60000]
# loss: 0.489634  [40100/60000]
# loss: 0.532621  [50100/60000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.414370
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.438696
#
# Epoch 3
# -------------------------------
# loss: 0.451227  [  100/60000]
# loss: 0.458040  [10100/60000]
# loss: 0.526351  [20100/60000]
# loss: 0.435441  [30100/60000]
# loss: 0.475358  [40100/60000]
# loss: 0.317033  [50100/60000]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.399519
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.426589
#
# Epoch 4
# -------------------------------
# loss: 0.436798  [  100/60000]
# loss: 0.424068  [10100/60000]
# loss: 0.512735  [20100/60000]
# loss: 0.531314  [30100/60000]
# loss: 0.462023  [40100/60000]
# loss: 0.380686  [50100/60000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.383610
#
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.414940
#
# Epoch 5
# -------------------------------
# loss: 0.502370  [  100/60000]
# loss: 0.400376  [10100/60000]
# loss: 0.419643  [20100/60000]
# loss: 0.358401  [30100/60000]
# loss: 0.357934  [40100/60000]
# loss: 0.364958  [50100/60000]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.351402
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.383278
#
# Epoch 6
# -------------------------------
# loss: 0.424854  [  100/60000]
# loss: 0.410331  [10100/60000]
# loss: 0.385703  [20100/60000]
# loss: 0.380437  [30100/60000]
# loss: 0.440355  [40100/60000]
# loss: 0.425231  [50100/60000]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.366764
#
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.401398
#
# Epoch 7
# -------------------------------
# loss: 0.447224  [  100/60000]
# loss: 0.333747  [10100/60000]
# loss: 0.315483  [20100/60000]
# loss: 0.411731  [30100/60000]
# loss: 0.345475  [40100/60000]
# loss: 0.349937  [50100/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.336544
#
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.373679
#
# Epoch 8
# -------------------------------
# loss: 0.359372  [  100/60000]
# loss: 0.479225  [10100/60000]
# loss: 0.429734  [20100/60000]
# loss: 0.447195  [30100/60000]
# loss: 0.434089  [40100/60000]
# loss: 0.400875  [50100/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.309615
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.351829
#
# Epoch 9
# -------------------------------
# loss: 0.318751  [  100/60000]
# loss: 0.377088  [10100/60000]
# loss: 0.361447  [20100/60000]
# loss: 0.308042  [30100/60000]
# loss: 0.403388  [40100/60000]
# loss: 0.405875  [50100/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.326741
#
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.364365
#
# Epoch 10
# -------------------------------
# loss: 0.359877  [  100/60000]
# loss: 0.424666  [10100/60000]
# loss: 0.284171  [20100/60000]
# loss: 0.415568  [30100/60000]
# loss: 0.484803  [40100/60000]
# loss: 0.391491  [50100/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.329679
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.373411
#
# Epoch 11
# -------------------------------
# loss: 0.330706  [  100/60000]
# loss: 0.379335  [10100/60000]
# loss: 0.679228  [20100/60000]
# loss: 0.384553  [30100/60000]
# loss: 0.485436  [40100/60000]
# loss: 0.478992  [50100/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.319769
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.364960
#
# Epoch 12
# -------------------------------
# loss: 0.346152  [  100/60000]
# loss: 0.416098  [10100/60000]
# loss: 0.378570  [20100/60000]
# loss: 0.371010  [30100/60000]
# loss: 0.238823  [40100/60000]
# loss: 0.328306  [50100/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.294955
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.344765
#
# Epoch 13
# -------------------------------
# loss: 0.278671  [  100/60000]
# loss: 0.434000  [10100/60000]
# loss: 0.276923  [20100/60000]
# loss: 0.447454  [30100/60000]
# loss: 0.233803  [40100/60000]
# loss: 0.395585  [50100/60000]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.284814
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.328993
#
# Epoch 14
# -------------------------------
# loss: 0.370816  [  100/60000]
# loss: 0.278495  [10100/60000]
# loss: 0.443727  [20100/60000]
# loss: 0.269160  [30100/60000]
# loss: 0.262450  [40100/60000]
# loss: 0.297987  [50100/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.324025
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.374877
#
# Epoch 15
# -------------------------------
# loss: 0.554871  [  100/60000]
# loss: 0.448574  [10100/60000]
# loss: 0.184896  [20100/60000]
# loss: 0.230028  [30100/60000]
# loss: 0.260975  [40100/60000]
# loss: 0.446578  [50100/60000]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.292556
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.338701
#
# Epoch 16
# -------------------------------
# loss: 0.332040  [  100/60000]
# loss: 0.262533  [10100/60000]
# loss: 0.392107  [20100/60000]
# loss: 0.582796  [30100/60000]
# loss: 0.314526  [40100/60000]
# loss: 0.280273  [50100/60000]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.297818
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.343069
#
# Epoch 17
# -------------------------------
# loss: 0.408731  [  100/60000]
# loss: 0.314174  [10100/60000]
# loss: 0.391084  [20100/60000]
# loss: 0.360595  [30100/60000]
# loss: 0.299307  [40100/60000]
# loss: 0.304300  [50100/60000]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.284604
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.335864
#
# Epoch 18
# -------------------------------
# loss: 0.318160  [  100/60000]
# loss: 0.310893  [10100/60000]
# loss: 0.343403  [20100/60000]
# loss: 0.228442  [30100/60000]
# loss: 0.335851  [40100/60000]
# loss: 0.281671  [50100/60000]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.278592
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.330935
#
# Epoch 19
# -------------------------------
# loss: 0.284171  [  100/60000]
# loss: 0.344815  [10100/60000]
# loss: 0.283271  [20100/60000]
# loss: 0.204040  [30100/60000]
# loss: 0.232350  [40100/60000]
# loss: 0.376249  [50100/60000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.283925
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.330523
#
# Epoch 20
# -------------------------------
# loss: 0.390767  [  100/60000]
# loss: 0.324049  [10100/60000]
# loss: 0.213401  [20100/60000]
# loss: 0.344567  [30100/60000]
# loss: 0.326605  [40100/60000]
# loss: 0.314106  [50100/60000]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.273866
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.325962
#
# Epoch 21
# -------------------------------
# loss: 0.218044  [  100/60000]
# loss: 0.380693  [10100/60000]
# loss: 0.384864  [20100/60000]
# loss: 0.398651  [30100/60000]
# loss: 0.289481  [40100/60000]
# loss: 0.344153  [50100/60000]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.264087
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.322298
#
# Epoch 22
# -------------------------------
# loss: 0.351027  [  100/60000]
# loss: 0.310405  [10100/60000]
# loss: 0.403599  [20100/60000]
# loss: 0.309957  [30100/60000]
# loss: 0.331627  [40100/60000]
# loss: 0.435233  [50100/60000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.271083
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.327483
#
# Epoch 23
# -------------------------------
# loss: 0.280057  [  100/60000]
# loss: 0.322498  [10100/60000]
# loss: 0.308281  [20100/60000]
# loss: 0.345543  [30100/60000]
# loss: 0.334429  [40100/60000]
# loss: 0.312001  [50100/60000]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.264657
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.323363
#
# Epoch 24
# -------------------------------
# loss: 0.380051  [  100/60000]
# loss: 0.414618  [10100/60000]
# loss: 0.301872  [20100/60000]
# loss: 0.318255  [30100/60000]
# loss: 0.265836  [40100/60000]
# loss: 0.316716  [50100/60000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.266208
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.326606
#
# Epoch 25
# -------------------------------
# loss: 0.251764  [  100/60000]
# loss: 0.478375  [10100/60000]
# loss: 0.326151  [20100/60000]
# loss: 0.348141  [30100/60000]
# loss: 0.377187  [40100/60000]
# loss: 0.282043  [50100/60000]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.265986
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.319812
#
# Epoch 26
# -------------------------------
# loss: 0.341518  [  100/60000]
# loss: 0.375667  [10100/60000]
# loss: 0.360703  [20100/60000]
# loss: 0.305608  [30100/60000]
# loss: 0.196554  [40100/60000]
# loss: 0.358464  [50100/60000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.256773
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.318411
#
# Epoch 27
# -------------------------------
# loss: 0.320082  [  100/60000]
# loss: 0.290686  [10100/60000]
# loss: 0.272425  [20100/60000]
# loss: 0.378822  [30100/60000]
# loss: 0.545663  [40100/60000]
# loss: 0.434015  [50100/60000]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.245522
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.311255
#
# Epoch 28
# -------------------------------
# loss: 0.240395  [  100/60000]
# loss: 0.304759  [10100/60000]
# loss: 0.279176  [20100/60000]
# loss: 0.276285  [30100/60000]
# loss: 0.197168  [40100/60000]
# loss: 0.275382  [50100/60000]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.262431
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.326295
#
# Epoch 29
# -------------------------------
# loss: 0.359919  [  100/60000]
# loss: 0.276555  [10100/60000]
# loss: 0.377445  [20100/60000]
# loss: 0.286137  [30100/60000]
# loss: 0.256799  [40100/60000]
# loss: 0.398518  [50100/60000]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.260721
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.327249
#
# Epoch 30
# -------------------------------
# loss: 0.322949  [  100/60000]
# loss: 0.321445  [10100/60000]
# loss: 0.254504  [20100/60000]
# loss: 0.233690  [30100/60000]
# loss: 0.286608  [40100/60000]
# loss: 0.226805  [50100/60000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.264945
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.333528
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Setup i", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Error Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, 's--', color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, 's--', color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, 'o-', c='crimson', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, 'o-', c='olive', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ ***ii) Optimizador (a SGD)***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier_ii = Classifier(autoencoder=pre_trained_autoencoder_c, use_bn=False).to(device)

# Freeze encoder and bottleneck
for param in classifier_ii.encoder.parameters():
    param.requires_grad = False

for param in classifier_ii.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.SGD(
    filter(lambda p: p.requires_grad, classifier_ii.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier0.named_parameters():
#     print(name, p.requires_grad)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier_ii, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier_ii, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier_ii, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.307736  [  100/60000]
# loss: 2.313540  [10100/60000]
# loss: 2.297364  [20100/60000]
# loss: 2.308990  [30100/60000]
# loss: 2.296841  [40100/60000]
# loss: 2.286653  [50100/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 2.296080
#
# Test Error:
#  Accuracy: 10.7%, Avg loss: 2.296200
#
# Epoch 2
# -------------------------------
# loss: 2.291335  [  100/60000]
# loss: 2.296728  [10100/60000]
# loss: 2.281851  [20100/60000]
# loss: 2.291293  [30100/60000]
# loss: 2.289039  [40100/60000]
# loss: 2.282168  [50100/60000]
# Test Error:
#  Accuracy: 18.0%, Avg loss: 2.287097
#
# Test Error:
#  Accuracy: 17.7%, Avg loss: 2.287231
#
# Epoch 3
# -------------------------------
# loss: 2.282919  [  100/60000]
# loss: 2.284602  [10100/60000]
# loss: 2.279750  [20100/60000]
# loss: 2.287324  [30100/60000]
# loss: 2.290222  [40100/60000]
# loss: 2.286390  [50100/60000]
# Test Error:
#  Accuracy: 21.1%, Avg loss: 2.277491
#
# Test Error:
#  Accuracy: 21.1%, Avg loss: 2.277653
#
# Epoch 4
# -------------------------------
# loss: 2.271206  [  100/60000]
# loss: 2.272529  [10100/60000]
# loss: 2.282047  [20100/60000]
# loss: 2.279233  [30100/60000]
# loss: 2.268480  [40100/60000]
# loss: 2.263523  [50100/60000]
# Test Error:
#  Accuracy: 26.7%, Avg loss: 2.266347
#
# Test Error:
#  Accuracy: 26.7%, Avg loss: 2.266561
#
# Epoch 5
# -------------------------------
# loss: 2.269952  [  100/60000]
# loss: 2.261822  [10100/60000]
# loss: 2.273086  [20100/60000]
# loss: 2.261580  [30100/60000]
# loss: 2.248608  [40100/60000]
# loss: 2.269941  [50100/60000]
# Test Error:
#  Accuracy: 30.7%, Avg loss: 2.252650
#
# Test Error:
#  Accuracy: 30.5%, Avg loss: 2.252933
#
# Epoch 6
# -------------------------------
# loss: 2.257003  [  100/60000]
# loss: 2.236747  [10100/60000]
# loss: 2.248437  [20100/60000]
# loss: 2.251917  [30100/60000]
# loss: 2.241957  [40100/60000]
# loss: 2.241539  [50100/60000]
# Test Error:
#  Accuracy: 34.0%, Avg loss: 2.235264
#
# Test Error:
#  Accuracy: 33.8%, Avg loss: 2.235620
#
# Epoch 7
# -------------------------------
# loss: 2.246234  [  100/60000]
# loss: 2.239141  [10100/60000]
# loss: 2.233282  [20100/60000]
# loss: 2.229522  [30100/60000]
# loss: 2.235018  [40100/60000]
# loss: 2.218423  [50100/60000]
# Test Error:
#  Accuracy: 41.1%, Avg loss: 2.212818
#
# Test Error:
#  Accuracy: 41.1%, Avg loss: 2.213258
#
# Epoch 8
# -------------------------------
# loss: 2.211482  [  100/60000]
# loss: 2.236180  [10100/60000]
# loss: 2.206307  [20100/60000]
# loss: 2.214206  [30100/60000]
# loss: 2.207975  [40100/60000]
# loss: 2.185343  [50100/60000]
# Test Error:
#  Accuracy: 52.8%, Avg loss: 2.183873
#
# Test Error:
#  Accuracy: 52.4%, Avg loss: 2.184429
#
# Epoch 9
# -------------------------------
# loss: 2.195461  [  100/60000]
# loss: 2.188939  [10100/60000]
# loss: 2.170740  [20100/60000]
# loss: 2.184468  [30100/60000]
# loss: 2.176324  [40100/60000]
# loss: 2.157349  [50100/60000]
# Test Error:
#  Accuracy: 49.0%, Avg loss: 2.146502
#
# Test Error:
#  Accuracy: 49.2%, Avg loss: 2.147222
#
# Epoch 10
# -------------------------------
# loss: 2.129471  [  100/60000]
# loss: 2.134897  [10100/60000]
# loss: 2.133828  [20100/60000]
# loss: 2.141116  [30100/60000]
# loss: 2.136528  [40100/60000]
# loss: 2.128304  [50100/60000]
# Test Error:
#  Accuracy: 45.9%, Avg loss: 2.099287
#
# Test Error:
#  Accuracy: 45.8%, Avg loss: 2.100200
#
# Epoch 11
# -------------------------------
# loss: 2.112271  [  100/60000]
# loss: 2.100662  [10100/60000]
# loss: 2.085514  [20100/60000]
# loss: 2.092404  [30100/60000]
# loss: 2.089030  [40100/60000]
# loss: 2.077297  [50100/60000]
# Test Error:
#  Accuracy: 44.8%, Avg loss: 2.040676
#
# Test Error:
#  Accuracy: 44.6%, Avg loss: 2.041833
#
# Epoch 12
# -------------------------------
# loss: 2.077336  [  100/60000]
# loss: 2.046826  [10100/60000]
# loss: 2.009283  [20100/60000]
# loss: 2.016396  [30100/60000]
# loss: 1.995969  [40100/60000]
# loss: 1.987045  [50100/60000]
# Test Error:
#  Accuracy: 44.4%, Avg loss: 1.971189
#
# Test Error:
#  Accuracy: 44.4%, Avg loss: 1.972646
#
# Epoch 13
# -------------------------------
# loss: 2.016856  [  100/60000]
# loss: 1.971388  [10100/60000]
# loss: 1.960072  [20100/60000]
# loss: 1.916338  [30100/60000]
# loss: 1.920043  [40100/60000]
# loss: 1.918193  [50100/60000]
# Test Error:
#  Accuracy: 45.0%, Avg loss: 1.893360
#
# Test Error:
#  Accuracy: 44.9%, Avg loss: 1.895164
#
# Epoch 14
# -------------------------------
# loss: 1.919986  [  100/60000]
# loss: 1.892343  [10100/60000]
# loss: 1.905463  [20100/60000]
# loss: 1.846857  [30100/60000]
# loss: 1.861446  [40100/60000]
# loss: 1.873521  [50100/60000]
# Test Error:
#  Accuracy: 46.4%, Avg loss: 1.812240
#
# Test Error:
#  Accuracy: 46.5%, Avg loss: 1.814412
#
# Epoch 15
# -------------------------------
# loss: 1.813143  [  100/60000]
# loss: 1.799634  [10100/60000]
# loss: 1.762432  [20100/60000]
# loss: 1.844950  [30100/60000]
# loss: 1.794012  [40100/60000]
# loss: 1.808802  [50100/60000]
# Test Error:
#  Accuracy: 46.9%, Avg loss: 1.733249
#
# Test Error:
#  Accuracy: 46.7%, Avg loss: 1.735843
#
# Epoch 16
# -------------------------------
# loss: 1.793180  [  100/60000]
# loss: 1.737903  [10100/60000]
# loss: 1.731167  [20100/60000]
# loss: 1.670254  [30100/60000]
# loss: 1.735214  [40100/60000]
# loss: 1.732413  [50100/60000]
# Test Error:
#  Accuracy: 48.3%, Avg loss: 1.659682
#
# Test Error:
#  Accuracy: 48.5%, Avg loss: 1.662625
#
# Epoch 17
# -------------------------------
# loss: 1.745499  [  100/60000]
# loss: 1.686127  [10100/60000]
# loss: 1.707764  [20100/60000]
# loss: 1.714785  [30100/60000]
# loss: 1.583932  [40100/60000]
# loss: 1.609546  [50100/60000]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.592549
#
# Test Error:
#  Accuracy: 49.3%, Avg loss: 1.595889
#
# Epoch 18
# -------------------------------
# loss: 1.620696  [  100/60000]
# loss: 1.691638  [10100/60000]
# loss: 1.591552  [20100/60000]
# loss: 1.589544  [30100/60000]
# loss: 1.612634  [40100/60000]
# loss: 1.632244  [50100/60000]
# Test Error:
#  Accuracy: 50.4%, Avg loss: 1.531695
#
# Test Error:
#  Accuracy: 50.5%, Avg loss: 1.535332
#
# Epoch 19
# -------------------------------
# loss: 1.600657  [  100/60000]
# loss: 1.545633  [10100/60000]
# loss: 1.498746  [20100/60000]
# loss: 1.579836  [30100/60000]
# loss: 1.511319  [40100/60000]
# loss: 1.517865  [50100/60000]
# Test Error:
#  Accuracy: 51.2%, Avg loss: 1.476535
#
# Test Error:
#  Accuracy: 51.3%, Avg loss: 1.480364
#
# Epoch 20
# -------------------------------
# loss: 1.539632  [  100/60000]
# loss: 1.435572  [10100/60000]
# loss: 1.443540  [20100/60000]
# loss: 1.467678  [30100/60000]
# loss: 1.413485  [40100/60000]
# loss: 1.493363  [50100/60000]
# Test Error:
#  Accuracy: 52.4%, Avg loss: 1.426496
#
# Test Error:
#  Accuracy: 52.2%, Avg loss: 1.430584
#
# Epoch 21
# -------------------------------
# loss: 1.483868  [  100/60000]
# loss: 1.459759  [10100/60000]
# loss: 1.390017  [20100/60000]
# loss: 1.458728  [30100/60000]
# loss: 1.564322  [40100/60000]
# loss: 1.548265  [50100/60000]
# Test Error:
#  Accuracy: 53.2%, Avg loss: 1.381349
#
# Test Error:
#  Accuracy: 53.0%, Avg loss: 1.385463
#
# Epoch 22
# -------------------------------
# loss: 1.493377  [  100/60000]
# loss: 1.315138  [10100/60000]
# loss: 1.465559  [20100/60000]
# loss: 1.449544  [30100/60000]
# loss: 1.418115  [40100/60000]
# loss: 1.389751  [50100/60000]
# Test Error:
#  Accuracy: 53.7%, Avg loss: 1.340568
#
# Test Error:
#  Accuracy: 53.4%, Avg loss: 1.344965
#
# Epoch 23
# -------------------------------
# loss: 1.338178  [  100/60000]
# loss: 1.353822  [10100/60000]
# loss: 1.338511  [20100/60000]
# loss: 1.329446  [30100/60000]
# loss: 1.494678  [40100/60000]
# loss: 1.337388  [50100/60000]
# Test Error:
#  Accuracy: 54.8%, Avg loss: 1.304744
#
# Test Error:
#  Accuracy: 54.5%, Avg loss: 1.309170
#
# Epoch 24
# -------------------------------
# loss: 1.367376  [  100/60000]
# loss: 1.408528  [10100/60000]
# loss: 1.379458  [20100/60000]
# loss: 1.350290  [30100/60000]
# loss: 1.351738  [40100/60000]
# loss: 1.308269  [50100/60000]
# Test Error:
#  Accuracy: 55.6%, Avg loss: 1.272320
#
# Test Error:
#  Accuracy: 55.3%, Avg loss: 1.277102
#
# Epoch 25
# -------------------------------
# loss: 1.366625  [  100/60000]
# loss: 1.287250  [10100/60000]
# loss: 1.292624  [20100/60000]
# loss: 1.363078  [30100/60000]
# loss: 1.287805  [40100/60000]
# loss: 1.290218  [50100/60000]
# Test Error:
#  Accuracy: 55.9%, Avg loss: 1.243576
#
# Test Error:
#  Accuracy: 55.6%, Avg loss: 1.248503
#
# Epoch 26
# -------------------------------
# loss: 1.329608  [  100/60000]
# loss: 1.284019  [10100/60000]
# loss: 1.380601  [20100/60000]
# loss: 1.362421  [30100/60000]
# loss: 1.234417  [40100/60000]
# loss: 1.434164  [50100/60000]
# Test Error:
#  Accuracy: 56.3%, Avg loss: 1.217886
#
# Test Error:
#  Accuracy: 56.2%, Avg loss: 1.222869
#
# Epoch 27
# -------------------------------
# loss: 1.194753  [  100/60000]
# loss: 1.293199  [10100/60000]
# loss: 1.352696  [20100/60000]
# loss: 1.341577  [30100/60000]
# loss: 1.274093  [40100/60000]
# loss: 1.257319  [50100/60000]
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.195085
#
# Test Error:
#  Accuracy: 56.6%, Avg loss: 1.200012
#
# Epoch 28
# -------------------------------
# loss: 1.319415  [  100/60000]
# loss: 1.404792  [10100/60000]
# loss: 1.224148  [20100/60000]
# loss: 1.274372  [30100/60000]
# loss: 1.281352  [40100/60000]
# loss: 1.346913  [50100/60000]
# Test Error:
#  Accuracy: 57.1%, Avg loss: 1.174658
#
# Test Error:
#  Accuracy: 56.6%, Avg loss: 1.179575
#
# Epoch 29
# -------------------------------
# loss: 1.279288  [  100/60000]
# loss: 1.260138  [10100/60000]
# loss: 1.259344  [20100/60000]
# loss: 1.202937  [30100/60000]
# loss: 1.260875  [40100/60000]
# loss: 1.173218  [50100/60000]
# Test Error:
#  Accuracy: 57.4%, Avg loss: 1.156035
#
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.161212
#
# Epoch 30
# -------------------------------
# loss: 1.243459  [  100/60000]
# loss: 1.207946  [10100/60000]
# loss: 1.263879  [20100/60000]
# loss: 1.312991  [30100/60000]
# loss: 1.226305  [40100/60000]
# loss: 1.186802  [50100/60000]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 1.139366
#
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.144555
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Setup ii", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Error Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, 's--', color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, 's--', color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, 'o-', c='crimson', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, 'o-', c='olive', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***iii) Dropout***

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier_iii = Classifier(autoencoder=pre_trained_autoencoder_c, use_bn=False, p=0.4).to(device)

# Freeze encoder and bottleneck
for param in classifier_iii.encoder.parameters():
    param.requires_grad = False

for param in classifier_iii.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, classifier_iii.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier0.named_parameters():
#     print(name, p.requires_grad)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 30
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier_iii, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier_iii, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier_iii, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Setup iii", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Error Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, 's--', color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, 's--', color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, 'o-', c='crimson', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, 'o-', c='olive', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Setup 0: Con Pre-entrenamiento y Codificador Freezado (Esquema Original)

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier0 = Classifier(autoencoder=pre_trained_autoencoder_c, use_bn=False).to(device)

# Freeze encoder and bottleneck
for param in classifier0.encoder.parameters():
    param.requires_grad = False

for param in classifier0.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, classifier0.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier0.named_parameters():
#     print(name, p.requires_grad)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 40
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier0, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier0, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier0, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.296029  [  100/60000]
# loss: 0.949334  [10100/60000]
# loss: 0.905833  [20100/60000]
# loss: 0.926767  [30100/60000]
# loss: 0.546201  [40100/60000]
# loss: 0.789976  [50100/60000]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.587305
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.599582
#
# Epoch 2
# -------------------------------
# loss: 0.664001  [  100/60000]
# loss: 0.675978  [10100/60000]
# loss: 0.658501  [20100/60000]
# loss: 0.529745  [30100/60000]
# loss: 0.466217  [40100/60000]
# loss: 0.586375  [50100/60000]
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.527788
#
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.543091
#
# Epoch 3
# -------------------------------
# loss: 0.545238  [  100/60000]
# loss: 0.616396  [10100/60000]
# loss: 0.533155  [20100/60000]
# loss: 0.651199  [30100/60000]
# loss: 0.450435  [40100/60000]
# loss: 0.598351  [50100/60000]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.478506
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.498094
#
# Epoch 4
# -------------------------------
# loss: 0.637340  [  100/60000]
# loss: 0.577595  [10100/60000]
# loss: 0.491706  [20100/60000]
# loss: 0.559642  [30100/60000]
# loss: 0.761289  [40100/60000]
# loss: 0.432517  [50100/60000]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.444083
#
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.464599
#
# Epoch 5
# -------------------------------
# loss: 0.506368  [  100/60000]
# loss: 0.381774  [10100/60000]
# loss: 0.462648  [20100/60000]
# loss: 0.526118  [30100/60000]
# loss: 0.523881  [40100/60000]
# loss: 0.445295  [50100/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.430528
#
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.455424
#
# Epoch 6
# -------------------------------
# loss: 0.490618  [  100/60000]
# loss: 0.382580  [10100/60000]
# loss: 0.466820  [20100/60000]
# loss: 0.414041  [30100/60000]
# loss: 0.619389  [40100/60000]
# loss: 0.478056  [50100/60000]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.415950
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.442029
#
# Epoch 7
# -------------------------------
# loss: 0.552809  [  100/60000]
# loss: 0.645782  [10100/60000]
# loss: 0.402628  [20100/60000]
# loss: 0.442116  [30100/60000]
# loss: 0.550196  [40100/60000]
# loss: 0.414646  [50100/60000]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.398647
#
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.426933
#
# Epoch 8
# -------------------------------
# loss: 0.650920  [  100/60000]
# loss: 0.372667  [10100/60000]
# loss: 0.450138  [20100/60000]
# loss: 0.537190  [30100/60000]
# loss: 0.456746  [40100/60000]
# loss: 0.461083  [50100/60000]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.392782
#
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.420978
#
# Epoch 9
# -------------------------------
# loss: 0.473382  [  100/60000]
# loss: 0.574043  [10100/60000]
# loss: 0.527941  [20100/60000]
# loss: 0.441158  [30100/60000]
# loss: 0.480601  [40100/60000]
# loss: 0.523857  [50100/60000]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.375662
#
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.405333
#
# Epoch 10
# -------------------------------
# loss: 0.522342  [  100/60000]
# loss: 0.548435  [10100/60000]
# loss: 0.425179  [20100/60000]
# loss: 0.521372  [30100/60000]
# loss: 0.483581  [40100/60000]
# loss: 0.428500  [50100/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.371751
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.402995
#
# Epoch 11
# -------------------------------
# loss: 0.461179  [  100/60000]
# loss: 0.470282  [10100/60000]
# loss: 0.365732  [20100/60000]
# loss: 0.393603  [30100/60000]
# loss: 0.407964  [40100/60000]
# loss: 0.451851  [50100/60000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.367093
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.399155
#
# Epoch 12
# -------------------------------
# loss: 0.449772  [  100/60000]
# loss: 0.462774  [10100/60000]
# loss: 0.472111  [20100/60000]
# loss: 0.446262  [30100/60000]
# loss: 0.445635  [40100/60000]
# loss: 0.369086  [50100/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.371781
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.407473
#
# Epoch 13
# -------------------------------
# loss: 0.516896  [  100/60000]
# loss: 0.609333  [10100/60000]
# loss: 0.514653  [20100/60000]
# loss: 0.588228  [30100/60000]
# loss: 0.352005  [40100/60000]
# loss: 0.458592  [50100/60000]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.377083
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.413540
#
# Epoch 14
# -------------------------------
# loss: 0.553602  [  100/60000]
# loss: 0.559574  [10100/60000]
# loss: 0.506419  [20100/60000]
# loss: 0.601410  [30100/60000]
# loss: 0.442519  [40100/60000]
# loss: 0.455194  [50100/60000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.361378
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.397083
#
# Epoch 15
# -------------------------------
# loss: 0.526723  [  100/60000]
# loss: 0.286546  [10100/60000]
# loss: 0.408142  [20100/60000]
# loss: 0.453070  [30100/60000]
# loss: 0.471753  [40100/60000]
# loss: 0.516694  [50100/60000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.355438
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.392884
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Esquema Baseline", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Pérdida Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, c='aqua', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, c='sienna', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Setup 1: Sin Pre-entrenamiento y Codificador Unfreezeado

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
random_autoencoder = AutoencoderConvolutional(n=128).to(device)
classifier1 = Classifier(autoencoder=random_autoencoder).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(classifier1.parameters(), lr=learning_rate)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 40
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier1, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier1, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier1, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.299817  [  100/60000]
# loss: 0.655479  [10100/60000]
# loss: 0.621426  [20100/60000]
# loss: 0.637386  [30100/60000]
# loss: 0.415286  [40100/60000]
# loss: 0.467524  [50100/60000]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.396410
#
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.422997
#
# Epoch 2
# -------------------------------
# loss: 0.410322  [  100/60000]
# loss: 0.466635  [10100/60000]
# loss: 0.385584  [20100/60000]
# loss: 0.528930  [30100/60000]
# loss: 0.428519  [40100/60000]
# loss: 0.223518  [50100/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.319535
#
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.351190
#
# Epoch 3
# -------------------------------
# loss: 0.423702  [  100/60000]
# loss: 0.453351  [10100/60000]
# loss: 0.378836  [20100/60000]
# loss: 0.347215  [30100/60000]
# loss: 0.297241  [40100/60000]
# loss: 0.401998  [50100/60000]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.287370
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.326833
#
# Epoch 4
# -------------------------------
# loss: 0.317825  [  100/60000]
# loss: 0.294674  [10100/60000]
# loss: 0.347586  [20100/60000]
# loss: 0.384134  [30100/60000]
# loss: 0.224864  [40100/60000]
# loss: 0.229527  [50100/60000]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.251483
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.296798
#
# Epoch 5
# -------------------------------
# loss: 0.289925  [  100/60000]
# loss: 0.331623  [10100/60000]
# loss: 0.303516  [20100/60000]
# loss: 0.148021  [30100/60000]
# loss: 0.300832  [40100/60000]
# loss: 0.228748  [50100/60000]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.234407
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.282421
#
# Epoch 6
# -------------------------------
# loss: 0.146010  [  100/60000]
# loss: 0.338049  [10100/60000]
# loss: 0.198549  [20100/60000]
# loss: 0.324209  [30100/60000]
# loss: 0.230405  [40100/60000]
# loss: 0.371197  [50100/60000]
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.211814
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.260644
#
# Epoch 7
# -------------------------------
# loss: 0.270699  [  100/60000]
# loss: 0.373856  [10100/60000]
# loss: 0.170646  [20100/60000]
# loss: 0.229127  [30100/60000]
# loss: 0.427616  [40100/60000]
# loss: 0.114537  [50100/60000]
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.200311
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.253489
#
# Epoch 8
# -------------------------------
# loss: 0.295736  [  100/60000]
# loss: 0.199013  [10100/60000]
# loss: 0.148737  [20100/60000]
# loss: 0.257228  [30100/60000]
# loss: 0.247722  [40100/60000]
# loss: 0.202468  [50100/60000]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.188230
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.251551
#
# Epoch 9
# -------------------------------
# loss: 0.230751  [  100/60000]
# loss: 0.158621  [10100/60000]
# loss: 0.184692  [20100/60000]
# loss: 0.190610  [30100/60000]
# loss: 0.149055  [40100/60000]
# loss: 0.323308  [50100/60000]
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.171773
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.237021
#
# Epoch 10
# -------------------------------
# loss: 0.140238  [  100/60000]
# loss: 0.326775  [10100/60000]
# loss: 0.249018  [20100/60000]
# loss: 0.199193  [30100/60000]
# loss: 0.326381  [40100/60000]
# loss: 0.270474  [50100/60000]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.160394
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.240275
#
# Epoch 11
# -------------------------------
# loss: 0.264712  [  100/60000]
# loss: 0.248102  [10100/60000]
# loss: 0.317567  [20100/60000]
# loss: 0.131225  [30100/60000]
# loss: 0.188563  [40100/60000]
# loss: 0.176260  [50100/60000]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.153626
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.236664
#
# Epoch 12
# -------------------------------
# loss: 0.157211  [  100/60000]
# loss: 0.234311  [10100/60000]
# loss: 0.200824  [20100/60000]
# loss: 0.205343  [30100/60000]
# loss: 0.141575  [40100/60000]
# loss: 0.220414  [50100/60000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.141132
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.231453
#
# Epoch 13
# -------------------------------
# loss: 0.128369  [  100/60000]
# loss: 0.134434  [10100/60000]
# loss: 0.193229  [20100/60000]
# loss: 0.275362  [30100/60000]
# loss: 0.180614  [40100/60000]
# loss: 0.210771  [50100/60000]
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.135603
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.230743
#
# Epoch 14
# -------------------------------
# loss: 0.169568  [  100/60000]
# loss: 0.135162  [10100/60000]
# loss: 0.138763  [20100/60000]
# loss: 0.175762  [30100/60000]
# loss: 0.158647  [40100/60000]
# loss: 0.169893  [50100/60000]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.126093
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.230906
#
# Epoch 15
# -------------------------------
# loss: 0.164565  [  100/60000]
# loss: 0.099681  [10100/60000]
# loss: 0.162918  [20100/60000]
# loss: 0.110231  [30100/60000]
# loss: 0.272300  [40100/60000]
# loss: 0.292515  [50100/60000]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.121406
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.231049
#
# Epoch 16
# -------------------------------
# loss: 0.293565  [  100/60000]
# loss: 0.156315  [10100/60000]
# loss: 0.125688  [20100/60000]
# loss: 0.243775  [30100/60000]
# loss: 0.174933  [40100/60000]
# loss: 0.126424  [50100/60000]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.133398
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.247850
#
# Epoch 17
# -------------------------------
# loss: 0.353050  [  100/60000]
# loss: 0.192609  [10100/60000]
# loss: 0.108937  [20100/60000]
# loss: 0.143931  [30100/60000]
# loss: 0.226908  [40100/60000]
# loss: 0.093704  [50100/60000]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.113631
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.231998
#
# Epoch 18
# -------------------------------
# loss: 0.146205  [  100/60000]
# loss: 0.090443  [10100/60000]
# loss: 0.169230  [20100/60000]
# loss: 0.141647  [30100/60000]
# loss: 0.157658  [40100/60000]
# loss: 0.192040  [50100/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.102983
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.234317
#
# Epoch 19
# -------------------------------
# loss: 0.124940  [  100/60000]
# loss: 0.091303  [10100/60000]
# loss: 0.236202  [20100/60000]
# loss: 0.097494  [30100/60000]
# loss: 0.144515  [40100/60000]
# loss: 0.222862  [50100/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.097716
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.234232
#
# Epoch 20
# -------------------------------
# loss: 0.085734  [  100/60000]
# loss: 0.160497  [10100/60000]
# loss: 0.140337  [20100/60000]
# loss: 0.147347  [30100/60000]
# loss: 0.074020  [40100/60000]
# loss: 0.232144  [50100/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.095756
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.239679
#
# Epoch 21
# -------------------------------
# loss: 0.218542  [  100/60000]
# loss: 0.151330  [10100/60000]
# loss: 0.080437  [20100/60000]
# loss: 0.097388  [30100/60000]
# loss: 0.184863  [40100/60000]
# loss: 0.150610  [50100/60000]
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.085949
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.234851
#
# Epoch 22
# -------------------------------
# loss: 0.116438  [  100/60000]
# loss: 0.100117  [10100/60000]
# loss: 0.123497  [20100/60000]
# loss: 0.103087  [30100/60000]
# loss: 0.151512  [40100/60000]
# loss: 0.146191  [50100/60000]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.086584
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.237571
#
# Epoch 23
# -------------------------------
# loss: 0.163106  [  100/60000]
# loss: 0.160942  [10100/60000]
# loss: 0.078644  [20100/60000]
# loss: 0.084882  [30100/60000]
# loss: 0.232947  [40100/60000]
# loss: 0.132585  [50100/60000]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.083549
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.243068
#
# Epoch 24
# -------------------------------
# loss: 0.151698  [  100/60000]
# loss: 0.083744  [10100/60000]
# loss: 0.090228  [20100/60000]
# loss: 0.119389  [30100/60000]
# loss: 0.094068  [40100/60000]
# loss: 0.156728  [50100/60000]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.075913
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.234139
#
# Epoch 25
# -------------------------------
# loss: 0.100730  [  100/60000]
# loss: 0.291939  [10100/60000]
# loss: 0.122002  [20100/60000]
# loss: 0.060699  [30100/60000]
# loss: 0.126235  [40100/60000]
# loss: 0.102834  [50100/60000]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.073903
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.248634
#
# Epoch 26
# -------------------------------
# loss: 0.099711  [  100/60000]
# loss: 0.191724  [10100/60000]
# loss: 0.135191  [20100/60000]
# loss: 0.192665  [30100/60000]
# loss: 0.099521  [40100/60000]
# loss: 0.109150  [50100/60000]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.066350
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.241314
#
# Epoch 27
# -------------------------------
# loss: 0.105244  [  100/60000]
# loss: 0.064919  [10100/60000]
# loss: 0.239237  [20100/60000]
# loss: 0.096223  [30100/60000]
# loss: 0.140081  [40100/60000]
# loss: 0.140616  [50100/60000]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.066257
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.244974
#
# Epoch 28
# -------------------------------
# loss: 0.131163  [  100/60000]
# loss: 0.176442  [10100/60000]
# loss: 0.165131  [20100/60000]
# loss: 0.175297  [30100/60000]
# loss: 0.133403  [40100/60000]
# loss: 0.132829  [50100/60000]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.064143
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.251790
#
# Epoch 29
# -------------------------------
# loss: 0.127303  [  100/60000]
# loss: 0.239250  [10100/60000]
# loss: 0.148756  [20100/60000]
# loss: 0.132844  [30100/60000]
# loss: 0.066546  [40100/60000]
# loss: 0.146677  [50100/60000]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.066437
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.256532
#
# Epoch 30
# -------------------------------
# loss: 0.132594  [  100/60000]
# loss: 0.160172  [10100/60000]
# loss: 0.061975  [20100/60000]
# loss: 0.091676  [30100/60000]
# loss: 0.131417  [40100/60000]
# loss: 0.034607  [50100/60000]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.065965
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.259066
#
# Epoch 31
# -------------------------------
# loss: 0.156822  [  100/60000]
# loss: 0.162911  [10100/60000]
# loss: 0.059108  [20100/60000]
# loss: 0.150615  [30100/60000]
# loss: 0.196332  [40100/60000]
# loss: 0.231662  [50100/60000]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.052369
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.256476
#
# Epoch 32
# -------------------------------
# loss: 0.132545  [  100/60000]
# loss: 0.044722  [10100/60000]
# loss: 0.097144  [20100/60000]
# loss: 0.171276  [30100/60000]
# loss: 0.124003  [40100/60000]
# loss: 0.147866  [50100/60000]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.052728
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.247760
#
# Epoch 33
# -------------------------------
# loss: 0.154184  [  100/60000]
# loss: 0.097076  [10100/60000]
# loss: 0.080540  [20100/60000]
# loss: 0.187125  [30100/60000]
# loss: 0.122519  [40100/60000]
# loss: 0.129830  [50100/60000]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.054465
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.269153
#
# Epoch 34
# -------------------------------
# loss: 0.110330  [  100/60000]
# loss: 0.084961  [10100/60000]
# loss: 0.096499  [20100/60000]
# loss: 0.125750  [30100/60000]
# loss: 0.266241  [40100/60000]
# loss: 0.120599  [50100/60000]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.053201
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.258954
#
# Epoch 35
# -------------------------------
# loss: 0.068546  [  100/60000]
# loss: 0.147327  [10100/60000]
# loss: 0.060021  [20100/60000]
# loss: 0.090728  [30100/60000]
# loss: 0.145720  [40100/60000]
# loss: 0.030313  [50100/60000]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.051357
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.263950
#
# Epoch 36
# -------------------------------
# loss: 0.079182  [  100/60000]
# loss: 0.111516  [10100/60000]
# loss: 0.086724  [20100/60000]
# loss: 0.109915  [30100/60000]
# loss: 0.065372  [40100/60000]
# loss: 0.098354  [50100/60000]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.043514
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.269519
#
# Epoch 37
# -------------------------------
# loss: 0.066361  [  100/60000]
# loss: 0.100862  [10100/60000]
# loss: 0.058624  [20100/60000]
# loss: 0.158661  [30100/60000]
# loss: 0.088246  [40100/60000]
# loss: 0.063749  [50100/60000]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.044448
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.257766
#
# Epoch 38
# -------------------------------
# loss: 0.067271  [  100/60000]
# loss: 0.129894  [10100/60000]
# loss: 0.070856  [20100/60000]
# loss: 0.105609  [30100/60000]
# loss: 0.069105  [40100/60000]
# loss: 0.120509  [50100/60000]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.040472
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.271710
#
# Epoch 39
# -------------------------------
# loss: 0.107500  [  100/60000]
# loss: 0.111285  [10100/60000]
# loss: 0.106528  [20100/60000]
# loss: 0.083677  [30100/60000]
# loss: 0.086819  [40100/60000]
# loss: 0.129379  [50100/60000]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.042252
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.271142
#
# Epoch 40
# -------------------------------
# loss: 0.089314  [  100/60000]
# loss: 0.124089  [10100/60000]
# loss: 0.099732  [20100/60000]
# loss: 0.146472  [30100/60000]
# loss: 0.043084  [40100/60000]
# loss: 0.152976  [50100/60000]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.037212
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.264101
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Esquema 1", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Pérdida Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, c='crimson', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, c='yellowgreen', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Setup 2: Con Pre-entrenamiento y Codificador Unfreezeado (Fine Tuning)

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
classifier2 = Classifier(autoencoder=pre_trained_autoencoder_c).to(device)

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(classifier2.parameters(), lr=learning_rate)

# -------- Statistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 40
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier2, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier2, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier2, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.295472  [  100/60000]
# loss: 0.940029  [10100/60000]
# loss: 0.726830  [20100/60000]
# loss: 0.746579  [30100/60000]
# loss: 0.611657  [40100/60000]
# loss: 0.632925  [50100/60000]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.547194
#
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.567443
#
# Epoch 2
# -------------------------------
# loss: 0.744476  [  100/60000]
# loss: 0.608170  [10100/60000]
# loss: 0.621219  [20100/60000]
# loss: 0.549854  [30100/60000]
# loss: 0.592916  [40100/60000]
# loss: 0.469797  [50100/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.473689
#
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.497092
#
# Epoch 3
# -------------------------------
# loss: 0.735427  [  100/60000]
# loss: 0.419359  [10100/60000]
# loss: 0.559972  [20100/60000]
# loss: 0.604346  [30100/60000]
# loss: 0.583785  [40100/60000]
# loss: 0.576735  [50100/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.432079
#
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.461519
#
# Epoch 4
# -------------------------------
# loss: 0.595131  [  100/60000]
# loss: 0.664451  [10100/60000]
# loss: 0.465877  [20100/60000]
# loss: 0.330542  [30100/60000]
# loss: 0.494208  [40100/60000]
# loss: 0.418140  [50100/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.405927
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.435200
#
# Epoch 5
# -------------------------------
# loss: 0.502015  [  100/60000]
# loss: 0.560382  [10100/60000]
# loss: 0.535163  [20100/60000]
# loss: 0.728292  [30100/60000]
# loss: 0.513931  [40100/60000]
# loss: 0.521091  [50100/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.395704
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.424198
#
# Epoch 6
# -------------------------------
# loss: 0.435040  [  100/60000]
# loss: 0.391445  [10100/60000]
# loss: 0.540675  [20100/60000]
# loss: 0.495846  [30100/60000]
# loss: 0.449615  [40100/60000]
# loss: 0.474524  [50100/60000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.368436
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.401792
#
# Epoch 7
# -------------------------------
# loss: 0.429010  [  100/60000]
# loss: 0.468203  [10100/60000]
# loss: 0.588732  [20100/60000]
# loss: 0.617622  [30100/60000]
# loss: 0.403332  [40100/60000]
# loss: 0.467771  [50100/60000]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.363892
#
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.392357
#
# Epoch 8
# -------------------------------
# loss: 0.343948  [  100/60000]
# loss: 0.550656  [10100/60000]
# loss: 0.400969  [20100/60000]
# loss: 0.427117  [30100/60000]
# loss: 0.381734  [40100/60000]
# loss: 0.421291  [50100/60000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.341869
#
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.376688
#
# Epoch 9
# -------------------------------
# loss: 0.326661  [  100/60000]
# loss: 0.556243  [10100/60000]
# loss: 0.472136  [20100/60000]
# loss: 0.459426  [30100/60000]
# loss: 0.314400  [40100/60000]
# loss: 0.365783  [50100/60000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.357076
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.394587
#
# Epoch 10
# -------------------------------
# loss: 0.315849  [  100/60000]
# loss: 0.502034  [10100/60000]
# loss: 0.493350  [20100/60000]
# loss: 0.458903  [30100/60000]
# loss: 0.304913  [40100/60000]
# loss: 0.336980  [50100/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.335577
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.374119
#
# Epoch 11
# -------------------------------
# loss: 0.519556  [  100/60000]
# loss: 0.439552  [10100/60000]
# loss: 0.353248  [20100/60000]
# loss: 0.659993  [30100/60000]
# loss: 0.374746  [40100/60000]
# loss: 0.431338  [50100/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.334102
#
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.372419
#
# Epoch 12
# -------------------------------
# loss: 0.351843  [  100/60000]
# loss: 0.542316  [10100/60000]
# loss: 0.265541  [20100/60000]
# loss: 0.395667  [30100/60000]
# loss: 0.361037  [40100/60000]
# loss: 0.419340  [50100/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.329339
#
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.368079
#
# Epoch 13
# -------------------------------
# loss: 0.306195  [  100/60000]
# loss: 0.261931  [10100/60000]
# loss: 0.288902  [20100/60000]
# loss: 0.353781  [30100/60000]
# loss: 0.295348  [40100/60000]
# loss: 0.503777  [50100/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.342153
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.384611
#
# Epoch 14
# -------------------------------
# loss: 0.514819  [  100/60000]
# loss: 0.491800  [10100/60000]
# loss: 0.480837  [20100/60000]
# loss: 0.421579  [30100/60000]
# loss: 0.518417  [40100/60000]
# loss: 0.360024  [50100/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.327040
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.371409
#
# Epoch 15
# -------------------------------
# loss: 0.523269  [  100/60000]
# loss: 0.252640  [10100/60000]
# loss: 0.332781  [20100/60000]
# loss: 0.369630  [30100/60000]
# loss: 0.474392  [40100/60000]
# loss: 0.425882  [50100/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.310630
#
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.355222
#
# Epoch 16
# -------------------------------
# loss: 0.486877  [  100/60000]
# loss: 0.364716  [10100/60000]
# loss: 0.399602  [20100/60000]
# loss: 0.429037  [30100/60000]
# loss: 0.383133  [40100/60000]
# loss: 0.376281  [50100/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.307559
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.354525
#
# Epoch 17
# -------------------------------
# loss: 0.446713  [  100/60000]
# loss: 0.402601  [10100/60000]
# loss: 0.377949  [20100/60000]
# loss: 0.417290  [30100/60000]
# loss: 0.477275  [40100/60000]
# loss: 0.371834  [50100/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.306933
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.353569
#
# Epoch 18
# -------------------------------
# loss: 0.468582  [  100/60000]
# loss: 0.281966  [10100/60000]
# loss: 0.486838  [20100/60000]
# loss: 0.428884  [30100/60000]
# loss: 0.500936  [40100/60000]
# loss: 0.418624  [50100/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.307611
#
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.357465
#
# Epoch 19
# -------------------------------
# loss: 0.483392  [  100/60000]
# loss: 0.381944  [10100/60000]
# loss: 0.395713  [20100/60000]
# loss: 0.239832  [30100/60000]
# loss: 0.364116  [40100/60000]
# loss: 0.476279  [50100/60000]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.297245
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.350791
#
# Epoch 20
# -------------------------------
# loss: 0.266646  [  100/60000]
# loss: 0.343203  [10100/60000]
# loss: 0.430411  [20100/60000]
# loss: 0.315214  [30100/60000]
# loss: 0.298451  [40100/60000]
# loss: 0.329616  [50100/60000]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.291073
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.344367
#
# Epoch 21
# -------------------------------
# loss: 0.325524  [  100/60000]
# loss: 0.416917  [10100/60000]
# loss: 0.275415  [20100/60000]
# loss: 0.346694  [30100/60000]
# loss: 0.463022  [40100/60000]
# loss: 0.457681  [50100/60000]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.293970
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.346891
#
# Epoch 22
# -------------------------------
# loss: 0.346789  [  100/60000]
# loss: 0.555606  [10100/60000]
# loss: 0.552923  [20100/60000]
# loss: 0.343055  [30100/60000]
# loss: 0.329385  [40100/60000]
# loss: 0.458588  [50100/60000]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.297153
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.347360
#
# Epoch 23
# -------------------------------
# loss: 0.331976  [  100/60000]
# loss: 0.456110  [10100/60000]
# loss: 0.339631  [20100/60000]
# loss: 0.404244  [30100/60000]
# loss: 0.395946  [40100/60000]
# loss: 0.270983  [50100/60000]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.292843
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.342884
#
# Epoch 24
# -------------------------------
# loss: 0.416209  [  100/60000]
# loss: 0.342616  [10100/60000]
# loss: 0.332599  [20100/60000]
# loss: 0.432834  [30100/60000]
# loss: 0.311435  [40100/60000]
# loss: 0.374521  [50100/60000]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.291171
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.340956
#
# Epoch 25
# -------------------------------
# loss: 0.354472  [  100/60000]
# loss: 0.323010  [10100/60000]
# loss: 0.437263  [20100/60000]
# loss: 0.286587  [30100/60000]
# loss: 0.384199  [40100/60000]
# loss: 0.314929  [50100/60000]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.293534
#
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.349523
#
# Epoch 26
# -------------------------------
# loss: 0.308565  [  100/60000]
# loss: 0.326519  [10100/60000]
# loss: 0.402569  [20100/60000]
# loss: 0.284173  [30100/60000]
# loss: 0.230746  [40100/60000]
# loss: 0.253416  [50100/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.296070
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.351410
#
# Epoch 27
# -------------------------------
# loss: 0.380270  [  100/60000]
# loss: 0.267639  [10100/60000]
# loss: 0.301048  [20100/60000]
# loss: 0.309612  [30100/60000]
# loss: 0.381663  [40100/60000]
# loss: 0.390099  [50100/60000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.277893
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.329763
#
# Epoch 28
# -------------------------------
# loss: 0.225606  [  100/60000]
# loss: 0.270457  [10100/60000]
# loss: 0.273053  [20100/60000]
# loss: 0.313120  [30100/60000]
# loss: 0.402445  [40100/60000]
# loss: 0.273876  [50100/60000]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.285305
#
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.344580
#
# Epoch 29
# -------------------------------
# loss: 0.506029  [  100/60000]
# loss: 0.410806  [10100/60000]
# loss: 0.377424  [20100/60000]
# loss: 0.438362  [30100/60000]
# loss: 0.219752  [40100/60000]
# loss: 0.245137  [50100/60000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.279861
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.334799
#
# Epoch 30
# -------------------------------
# loss: 0.259505  [  100/60000]
# loss: 0.447418  [10100/60000]
# loss: 0.330775  [20100/60000]
# loss: 0.350320  [30100/60000]
# loss: 0.387272  [40100/60000]
# loss: 0.394756  [50100/60000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.273539
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.329540
#
# Epoch 31
# -------------------------------
# loss: 0.303385  [  100/60000]
# loss: 0.278112  [10100/60000]
# loss: 0.406008  [20100/60000]
# loss: 0.371250  [30100/60000]
# loss: 0.371131  [40100/60000]
# loss: 0.356461  [50100/60000]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.277554
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.335441
#
# Epoch 32
# -------------------------------
# loss: 0.269613  [  100/60000]
# loss: 0.352062  [10100/60000]
# loss: 0.290216  [20100/60000]
# loss: 0.392285  [30100/60000]
# loss: 0.307971  [40100/60000]
# loss: 0.275728  [50100/60000]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.266159
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.325922
#
# Epoch 33
# -------------------------------
# loss: 0.360240  [  100/60000]
# loss: 0.426200  [10100/60000]
# loss: 0.482072  [20100/60000]
# loss: 0.249240  [30100/60000]
# loss: 0.294786  [40100/60000]
# loss: 0.458895  [50100/60000]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.274714
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.333299
#
# Epoch 34
# -------------------------------
# loss: 0.551105  [  100/60000]
# loss: 0.349507  [10100/60000]
# loss: 0.242411  [20100/60000]
# loss: 0.263895  [30100/60000]
# loss: 0.310465  [40100/60000]
# loss: 0.351781  [50100/60000]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.281543
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.338328
#
# Epoch 35
# -------------------------------
# loss: 0.379346  [  100/60000]
# loss: 0.304474  [10100/60000]
# loss: 0.392269  [20100/60000]
# loss: 0.360078  [30100/60000]
# loss: 0.289047  [40100/60000]
# loss: 0.295212  [50100/60000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.267731
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.327791
#
# Epoch 36
# -------------------------------
# loss: 0.329709  [  100/60000]
# loss: 0.322737  [10100/60000]
# loss: 0.344989  [20100/60000]
# loss: 0.346302  [30100/60000]
# loss: 0.214432  [40100/60000]
# loss: 0.348361  [50100/60000]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.269302
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.322232
#
# Epoch 37
# -------------------------------
# loss: 0.322466  [  100/60000]
# loss: 0.280254  [10100/60000]
# loss: 0.278450  [20100/60000]
# loss: 0.386572  [30100/60000]
# loss: 0.365804  [40100/60000]
# loss: 0.319603  [50100/60000]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.266280
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.325981
#
# Epoch 38
# -------------------------------
# loss: 0.279054  [  100/60000]
# loss: 0.289050  [10100/60000]
# loss: 0.411020  [20100/60000]
# loss: 0.525961  [30100/60000]
# loss: 0.347983  [40100/60000]
# loss: 0.423820  [50100/60000]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.268137
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.325723
#
# Epoch 39
# -------------------------------
# loss: 0.306545  [  100/60000]
# loss: 0.276572  [10100/60000]
# loss: 0.333560  [20100/60000]
# loss: 0.330056  [30100/60000]
# loss: 0.304937  [40100/60000]
# loss: 0.355925  [50100/60000]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.267085
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.328435
#
# Epoch 40
# -------------------------------
# loss: 0.523167  [  100/60000]
# loss: 0.370650  [10100/60000]
# loss: 0.280171  [20100/60000]
# loss: 0.389126  [30100/60000]
# loss: 0.376699  [40100/60000]
# loss: 0.291539  [50100/60000]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.256848
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.316713
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Esquema 2", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Pérdida Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, c='blueviolet', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, c='springgreen', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Matriz de confusión

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Put model in evaluation mode
classifier2.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for X, y in valid_dataloader:
        X, y = X.to(device), y.to(device)
        outputs = classifier2(X)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

# Compute confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Plot
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=[str(i) for i in range(10)],
            yticklabels=[str(i) for i in range(10)])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Matriz de confusión - Retried Esquema")
plt.show()

# %% [markdown]
# ## Setup 3: Sin Pre-entrenamiento y Codificador Freezeado

# %%
# -------- Dataloaders --------
train_dataloader = DataLoader(train_set_orig, batch_size=100, shuffle = True)
valid_dataloader = DataLoader(valid_set_orig, batch_size=100, shuffle = False)

# -------- Loss Function --------
loss_fn = nn.CrossEntropyLoss()

# -------- Model --------
random_autoencoder = AutoencoderConvolutional(n=128).to(device)
classifier3 = Classifier(autoencoder=random_autoencoder).to(device)

# Freeze encoder and bottleneck
for param in classifier3.encoder.parameters():
    param.requires_grad = False

for param in classifier3.bottleneck.parameters():
    param.requires_grad = False

# -------- Optimizer --------
learning_rate = 1e-3
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, classifier3.parameters()),
    lr=learning_rate
)

# DEBUG
# for name, p in classifier3.named_parameters():
#     print(name, p.requires_grad)

# -------- Stadistics --------
train_loss_mean = []
train_inc_loss_mean = []
valid_loss_mean = []
train_acc_frac = []
valid_acc_frac = []

# %%
EPOCHS = 40
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_inc_loss = train_loop(train_dataloader, classifier3, loss_fn, optimizer)
    train_loss, train_acc = valid_loop_clasiffier(train_dataloader, classifier3, loss_fn)
    valid_loss, valid_acc = valid_loop_clasiffier(valid_dataloader, classifier3, loss_fn)

    train_inc_loss_mean.append(train_inc_loss)
    train_loss_mean.append(train_loss)
    valid_loss_mean.append(valid_loss)
    train_acc_frac.append(train_acc)
    valid_acc_frac.append(valid_acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.292909  [  100/60000]
# loss: 0.724312  [10100/60000]
# loss: 0.595103  [20100/60000]
# loss: 0.789662  [30100/60000]
# loss: 0.448027  [40100/60000]
# loss: 0.550730  [50100/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.410990
#
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.437970
#
# Epoch 2
# -------------------------------
# loss: 0.359970  [  100/60000]
# loss: 0.517683  [10100/60000]
# loss: 0.540425  [20100/60000]
# loss: 0.474368  [30100/60000]
# loss: 0.277276  [40100/60000]
# loss: 0.249720  [50100/60000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.365122
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.391126
#
# Epoch 3
# -------------------------------
# loss: 0.455726  [  100/60000]
# loss: 0.522709  [10100/60000]
# loss: 0.606361  [20100/60000]
# loss: 0.315902  [30100/60000]
# loss: 0.428328  [40100/60000]
# loss: 0.396171  [50100/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.337412
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.367376
#
# Epoch 4
# -------------------------------
# loss: 0.375473  [  100/60000]
# loss: 0.480358  [10100/60000]
# loss: 0.445507  [20100/60000]
# loss: 0.469020  [30100/60000]
# loss: 0.536248  [40100/60000]
# loss: 0.415232  [50100/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.321360
#
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.354321
#
# Epoch 5
# -------------------------------
# loss: 0.450826  [  100/60000]
# loss: 0.275209  [10100/60000]
# loss: 0.394233  [20100/60000]
# loss: 0.363248  [30100/60000]
# loss: 0.405550  [40100/60000]
# loss: 0.445202  [50100/60000]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.292105
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.328120
#
# Epoch 6
# -------------------------------
# loss: 0.344469  [  100/60000]
# loss: 0.631318  [10100/60000]
# loss: 0.566485  [20100/60000]
# loss: 0.376428  [30100/60000]
# loss: 0.284456  [40100/60000]
# loss: 0.457316  [50100/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.299130
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.336708
#
# Epoch 7
# -------------------------------
# loss: 0.283213  [  100/60000]
# loss: 0.522211  [10100/60000]
# loss: 0.321832  [20100/60000]
# loss: 0.300034  [30100/60000]
# loss: 0.422539  [40100/60000]
# loss: 0.389211  [50100/60000]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.287524
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.331926
#
# Epoch 8
# -------------------------------
# loss: 0.206935  [  100/60000]
# loss: 0.260341  [10100/60000]
# loss: 0.248046  [20100/60000]
# loss: 0.289227  [30100/60000]
# loss: 0.404983  [40100/60000]
# loss: 0.305366  [50100/60000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.281248
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.321980
#
# Epoch 9
# -------------------------------
# loss: 0.508979  [  100/60000]
# loss: 0.309520  [10100/60000]
# loss: 0.357665  [20100/60000]
# loss: 0.269528  [30100/60000]
# loss: 0.418421  [40100/60000]
# loss: 0.374078  [50100/60000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.271535
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.313763
#
# Epoch 10
# -------------------------------
# loss: 0.329223  [  100/60000]
# loss: 0.440121  [10100/60000]
# loss: 0.212359  [20100/60000]
# loss: 0.340307  [30100/60000]
# loss: 0.242731  [40100/60000]
# loss: 0.291553  [50100/60000]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.275955
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.325913
#
# Epoch 11
# -------------------------------
# loss: 0.434311  [  100/60000]
# loss: 0.390961  [10100/60000]
# loss: 0.352544  [20100/60000]
# loss: 0.209279  [30100/60000]
# loss: 0.320675  [40100/60000]
# loss: 0.352847  [50100/60000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.260260
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.313201
#
# Epoch 12
# -------------------------------
# loss: 0.224571  [  100/60000]
# loss: 0.197697  [10100/60000]
# loss: 0.266655  [20100/60000]
# loss: 0.340335  [30100/60000]
# loss: 0.307962  [40100/60000]
# loss: 0.364035  [50100/60000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.257634
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.309279
#
# Epoch 13
# -------------------------------
# loss: 0.367717  [  100/60000]
# loss: 0.328323  [10100/60000]
# loss: 0.241140  [20100/60000]
# loss: 0.223589  [30100/60000]
# loss: 0.242086  [40100/60000]
# loss: 0.238347  [50100/60000]
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.245106
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.300614
#
# Epoch 14
# -------------------------------
# loss: 0.351480  [  100/60000]
# loss: 0.345845  [10100/60000]
# loss: 0.260949  [20100/60000]
# loss: 0.342932  [30100/60000]
# loss: 0.262995  [40100/60000]
# loss: 0.322645  [50100/60000]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.249794
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.308036
#
# Epoch 15
# -------------------------------
# loss: 0.442237  [  100/60000]
# loss: 0.253778  [10100/60000]
# loss: 0.305278  [20100/60000]
# loss: 0.270842  [30100/60000]
# loss: 0.275053  [40100/60000]
# loss: 0.323686  [50100/60000]
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.243966
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.300193
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

fig.suptitle("Esquema 3", fontsize=20)

# --- Gráfico 1: Cross Entropy Loss ---
axes[0].set_title("Cross Entropy Loss", fontsize=16)
axes[0].set_xlabel("Épocas", fontsize=12)
axes[0].set_ylabel("Pérdida Promedio", fontsize=12)
axes[0].plot(range(EPOCHS), train_loss_mean, color='blue', label='Entrenamiento')
axes[0].plot(range(EPOCHS), valid_loss_mean, color='green', label='Validación')
# axes[0].plot(range(EPOCHS), train_inc_loss_mean, 'x:', color='tab:red', label='Entrenamiento Inc')
axes[0].legend()
axes[0].grid(True)

# --- Gráfico 2: Precisión ---
axes[1].set_title("Accuracy", fontsize=16)
axes[1].set_xlabel("Épocas", fontsize=12)
axes[1].set_ylabel("Precisión", fontsize=12)
axes[1].plot(range(EPOCHS), train_acc_frac, c='gold', label='Entrenamiento')
axes[1].plot(range(EPOCHS), valid_acc_frac, c='olive', label='Validación')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
